# %% [markdown]
# ## TEAM-EDINBURGH
#
#
# Project Title - The Indian Start-Up Case
#
# Context
# The data for this project spans from 2018-2019. Our goal will be to satisfy the processes for handling the data and also provide a detailed analysis of the process using the CRISP-DM data analysis framework.
#
# This Notebook will include conclusions on the following :
#
# * Asking the relevant questions and stating some hypothesis.
# * Cleaning the data.
#
# Questions?
#
# * Do companies in certain sectors tend to receive more funding than others?
#
# * Is there a correlation between the stage of development of a company and the amount of funding it receives?
#
# * Are companies with more founders more likely to receive larger amounts of funding?
#
# * Are there any patterns in the location of a company's headquarters and the amount of funding it receives?
#
# * Does the number of investors in a company tend to impact the amount of funding it receives?
#
# * Founders: How many founders are associated with each company? What is the average number of founders?
#
# * What are the top 10 companies with the highest funding?
#
#
# Hypothesis!
#
# * Startups in the e-commerce and fintech sectors receive more funding compared to other sectors in India.
#
# * There is a positive correlation between the stage of development of a company and the amount of funding it receives in India.
#
# * Companies with a larger number of founders are more likely to receive higher amounts of funding in India.
#
# * Startups headquartered in major metropolitan areas such as Mumbai, Bangalore, and Delhi are more likely to receive larger amounts of funding in India.
#
# * The number of investors in a company is positively correlated with the amount of funding it receives in India.
#
# * Is there a relationship between the sector of a company and the amount of funding it receives?
#
# * Is there a difference in the average funding received by companies headquartered in different regions?

# %% [markdown]
# ## Importing libraries & accessing the size and shape of the data

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
ind_2018 = pd.read_csv('C:\\Users\\GILBERT\\Downloads\\DAP2\Indian Start-up Project\\startup_funding2018.csv')
ind_2019 = pd.read_csv('C:\\Users\\GILBERT\\Downloads\\DAP2\\Indian Start-up Project\\startup_funding2019.csv')
ind_2020 = pd.read_csv('C:\\Users\\GILBERT\\Downloads\\DAP2\\Indian Start-up Project\\startup_funding2020.csv')
ind_2021 = pd.read_csv('C:\\Users\\GILBERT\\Downloads\\DAP2\\Indian Start-up Project\\startup_funding2021.csv')

# %%
ind_2018.head()
# Out:
#       Company Name                                           Industry  \
# 0  TheCollegeFever  Brand Marketing, Event Promotion, Marketing, S...
# 1  Happy Cow Dairy                               Agriculture, Farming
# 2       MyLoanCare   Credit, Financial Services, Lending, Marketplace
# 3      PayMe India                        Financial Services, FinTech
# 4         Eunimart                 E-Commerce Platforms, Retail, SaaS
#
#   Round/Series       Amount                          Location  \
# 0         Seed       250000       Bangalore, Karnataka, India
# 1         Seed  ₹40,000,000        Mumbai, Maharashtra, India
# 2     Series A  ₹65,000,000           Gurgaon, Haryana, India
# 3        Angel      2000000       Noida, Uttar Pradesh, India
# 4         Seed            —  Hyderabad, Andhra Pradesh, India
#
#                                        About Company
# 0  TheCollegeFever is a hub for fun, fiesta and f...
# 1  A startup which aggregates milk from dairy far...
# 2          Leading Online Loans Marketplace in India
# 3  PayMe India is an innovative FinTech organizat...
# 4  Eunimart is a one stop solution for merchants ...

# %%
ind_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 526 entries, 0 to 525
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company Name   526 non-null    object
#  1   Industry       526 non-null    object
#  2   Round/Series   526 non-null    object
#  3   Amount         526 non-null    object
#  4   Location       526 non-null    object
#  5   About Company  526 non-null    object
# dtypes: object(6)
# memory usage: 24.8+ KB

# %%
ind_2018.isna().sum()
# Out:
# Company Name     0
# Industry         0
# Round/Series     0
# Amount           0
# Location         0
# About Company    0
# dtype: int64

# %% [markdown]
# ## Filtering the data ,replacing and rename values & a date series(random)

# %%
ind_2018['Year']=2018
ind_2018['Founded']='NaN'
ind_2018= ind_2018.rename(columns={'Company Name': 'Company/Brand'})
ind_2018= ind_2018.rename(columns={'Industry': 'Sector'})
ind_2018= ind_2018.rename(columns={'Location': 'HeadQuarter'})
ind_2018= ind_2018.rename(columns={'Amount': 'Amount($)'})
ind_2018= ind_2018.rename(columns={'Round/Series': 'Stage'})
ind_2018.drop('About Company',axis=1,inplace=True)

# %%
# replace empty values with NaN
ind_2018['Sector'].replace('—', pd.np.nan, inplace=True)
# Out:
# C:\Users\GILBERT\AppData\Local\Temp\ipykernel_13168\2826083760.py:2: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead.
#   ind_2018['Sector'].replace('—', pd.np.nan, inplace=True)

# %%
ind_2018.loc[58, 'Sector'] = 'Entertainment'
ind_2018.loc[105, 'Sector'] = 'Finance'
ind_2018.loc[121, 'Sector'] = 'Automotive'
ind_2018.loc[146, 'Sector'] = 'Automotive'
ind_2018.loc[153, 'Sector'] = 'Food'
ind_2018.loc[174, 'Sector'] = 'Technology'
ind_2018.loc[181, 'Sector'] = 'Finance'
ind_2018.loc[210, 'Sector'] = 'Automotive'
ind_2018.loc[230, 'Sector'] = 'Real Estate'
ind_2018.loc[235, 'Sector'] = 'Technology'
ind_2018.loc[238, 'Sector'] = 'Technology'
ind_2018.loc[242, 'Sector'] = 'Real Estate'
ind_2018.loc[243, 'Sector'] = 'Technology'
ind_2018.loc[247, 'Sector'] = 'Technology'
ind_2018.loc[251, 'Sector'] = 'Wellness'
ind_2018.loc[257, 'Sector'] = 'Marketing'
ind_2018.loc[258, 'Sector'] = 'Marketing'
ind_2018.loc[259, 'Sector'] = 'E-Commerce'
ind_2018.loc[257, 'Sector'] = 'Marketing'
ind_2018.loc[294, 'Sector'] = 'Transportation'
ind_2018.loc[325, 'Sector'] = 'Technology'
ind_2018.loc[326, 'Sector'] = 'Finance'
ind_2018.loc[346, 'Sector'] = 'Finance'
ind_2018.loc[398, 'Sector'] = 'Finance'
ind_2018.loc[457, 'Sector'] = 'Agriculture'
ind_2018.loc[472, 'Sector'] = 'Technology'
ind_2018.loc[473, 'Sector'] = 'Technology'
ind_2018.loc[476, 'Sector'] = 'Technology'
ind_2018.loc[478, 'Sector'] = 'Wellness/Beauty'
ind_2018.loc[480, 'Sector'] = 'Hospitality'
ind_2018.loc[510, 'Sector'] = 'Technology'

# %%
ind_2018.head(511)
# Out:
#        Company/Brand                                             Sector  \
# 0    TheCollegeFever  Brand Marketing, Event Promotion, Marketing, S...
# 1    Happy Cow Dairy                               Agriculture, Farming
# 2         MyLoanCare   Credit, Financial Services, Lending, Marketplace
# 3        PayMe India                        Financial Services, FinTech
# 4           Eunimart                 E-Commerce Platforms, Retail, SaaS
# ..               ...                                                ...
# 506           Verzeo                                         E-Learning
# 507           Haazri                 Food and Beverage, Snack Food, Tea
# 508    Connect India            Delivery Service, E-Commerce, Logistics
# 509          Flyrobe                         Fashion, Lifestyle, Rental
# 510         Scholify                                         Technology
#
#         Stage     Amount($)                       HeadQuarter  Year Founded
# 0        Seed        250000       Bangalore, Karnataka, India  2018     NaN
# 1        Seed   ₹40,000,000        Mumbai, Maharashtra, India  2018     NaN
# 2    Series A   ₹65,000,000           Gurgaon, Haryana, India  2018     NaN
# 3       Angel       2000000       Noida, Uttar Pradesh, India  2018     NaN
# 4        Seed             —  Hyderabad, Andhra Pradesh, India  2018     NaN
# ..        ...           ...                               ...   ...     ...
# 506  Series A       5000000       Bangalore, Karnataka, India  2018     NaN
# 507      Seed   ₹12,500,000        Mumbai, Maharashtra, India  2018     NaN
# 508     Angel             —           New Delhi, Delhi, India  2018     NaN
# 509  Series B  ₹264,000,000        Mumbai, Maharashtra, India  2018     NaN
# 510  Pre-Seed             —       Bengaluru, Karnataka, India  2018     NaN
#
# [511 rows x 7 columns]

# %%
ind_2018.isna().sum()
# Out:
# Company/Brand    0
# Sector           0
# Stage            0
# Amount($)        0
# HeadQuarter      0
# Year             0
# Founded          0
# dtype: int64

# %% [markdown]
# ## Filling the anomalies in this column by containing the valid values and replacing the missing values

# %%
valid_stages = ['Venture - Series Unknown','Seed', 'Angel', 'Series A', 'Series B', 'Pre-Seed', 'Grant', 'Series H', 
                'Series A', 'Series C', 'Series E', 'Corporate Round','Series D']

ind_2018.loc[~ind_2018['Stage'].isin(valid_stages), 'Stage'] = np.nan

# %%
# # create a DatetimeIndex with dates for the entire year
date_range = pd.date_range(start='2018-01-01', end='2018-12-31', freq='D')

# # create a new column 'Date' with random dates within the year 2018
ind_2018['Date'] = np.random.choice(date_range, size=len(ind_2018))

ind_2018 = ind_2018.sort_values('Date')

ind_2018['Date'] = pd.to_datetime(ind_2018['Date'], format='%Y-%m-%d')

# %%
ind_2018.set_index('Date',inplace=True)

# %% [markdown]
# ## Changing the shape of the amount col & currency(rates conidered),filling the missing values with mean of the column.

# %%
def convert_to_dollars(value):
    if pd.isnull(value):
        return np.nan
    elif isinstance(value, float):
        return str(value)
    elif '$' in value:
        return value
    elif '₹' in value:
        return '$' + str(round(float(value.split('₹')[1].replace(',', '')) / 68.44, 2))
    else:
        return '$' + str(float(value) / 68.44)


# convert values in 'Amount($)' column to strings
ind_2018['Amount($)'] = ind_2018['Amount($)'].astype(str)

ind_2018['Amount($)'] = ind_2018['Amount($)'].str.replace('[^\d\.]', '')

ind_2018['Amount($)'].replace('', np.nan, inplace=True)

ind_2018['Amount($)'] = ind_2018['Amount($)'].astype(float)

ind_2018['Amount($)'] = ind_2018['Amount($)'].apply(convert_to_dollars)
# Out:
# C:\Users\GILBERT\AppData\Local\Temp\ipykernel_13168\4169188906.py:17: FutureWarning: The default value of regex will change from True to False in a future version.
#   ind_2018['Amount($)'] = ind_2018['Amount($)'].str.replace('[^\d\.]', '')

# %%
# # convert the 'Amount' column to a numeric data type
ind_2018['Amount($)'] = pd.to_numeric(ind_2018['Amount($)'])
ind_2018['Amount($)'] = pd.to_numeric(ind_2018['Amount($)'])

# %%
ind_2018.describe()
# Out:
#           Amount($)    Year
# count  3.780000e+02   526.0
# mean   2.391683e+08  2018.0
# std    1.374900e+09     0.0
# min    7.500000e+03  2018.0
# 25%    1.000000e+06  2018.0
# 50%    5.800000e+06  2018.0
# 75%    5.000000e+07  2018.0
# max    2.000000e+10  2018.0

# %%
ind_2018.duplicated()
# Out:
# Date
# 2018-01-01    False
# 2018-01-01    False
# 2018-01-01    False
# 2018-01-01    False
# 2018-01-02    False
#               ...
# 2018-12-29    False
# 2018-12-29    False
# 2018-12-30    False
# 2018-12-30    False
# 2018-12-31    False
# Length: 526, dtype: bool

# %%
ind_2018.isna().sum()
# Out:
# Company/Brand      0
# Sector             0
# Stage             36
# Amount($)        148
# HeadQuarter        0
# Year               0
# Founded            0
# dtype: int64

# %%
ind_2018.head()
# Out:
#                               Company/Brand  \
# Date
# 2018-01-01  Hashtag Loyalty Private Limited
# 2018-01-01                        Simulanis
# 2018-01-01     Wellthy Therapeutics Pvt Ltd
# 2018-01-01                            mfine
# 2018-01-02            Pandorum Technologies
#
#                                                        Sector     Stage  \
# Date
# 2018-01-01  Analytics, CRM, Loyalty Programs, Machine Lear...      Seed
# 2018-01-01                                           Training      Seed
# 2018-01-01                              Health Care, Hospital      Seed
# 2018-01-01                              Health Care, Hospital  Series A
# 2018-01-02                                      Biotechnology  Series A
#
#               Amount($)                  HeadQuarter  Year Founded
# Date
# 2018-01-01          NaN   Mumbai, Maharashtra, India  2018     NaN
# 2018-01-01     500000.0      New Delhi, Delhi, India  2018     NaN
# 2018-01-01  135000000.0   Mumbai, Maharashtra, India  2018     NaN
# 2018-01-01    4200000.0  Bengaluru, Karnataka, India  2018     NaN
# 2018-01-02    3600000.0  Bengaluru, Karnataka, India  2018     NaN

# %%
# Create a histogram of the 'Amount' column
plt.hist(ind_2018['Amount($)'], bins=20)
plt.title('Distribution of Amount')
plt.xlabel('Amount($)')
plt.ylabel('Frequency')
plt.show()

# %%
ind_2018['Amount($)'] = ind_2018['Amount($)'].fillna(ind_2018['Amount($)'].median())

# %%
ind_2018['Amount($)'] = ind_2018['Amount($)'].astype(int)

# %%
ind_2018.isna().sum()
# Out:
# Company/Brand     0
# Sector            0
# Stage            36
# Amount($)         0
# HeadQuarter       0
# Year              0
# Founded           0
# dtype: int64

# %%
ind_2018.head(100)
# Out:
#                               Company/Brand  \
# Date
# 2018-01-01  Hashtag Loyalty Private Limited
# 2018-01-01                        Simulanis
# 2018-01-01     Wellthy Therapeutics Pvt Ltd
# 2018-01-01                            mfine
# 2018-01-02            Pandorum Technologies
# ...                                     ...
# 2018-03-07         Theranosis Life Sciences
# 2018-03-08                         Billdesk
# 2018-03-08                        RAHI Care
# 2018-03-08                       Chai Kings
# 2018-03-09                     HealthAssure
#
#                                                        Sector  \
# Date
# 2018-01-01  Analytics, CRM, Loyalty Programs, Machine Lear...
# 2018-01-01                                           Training
# 2018-01-01                              Health Care, Hospital
# 2018-01-01                              Health Care, Hospital
# 2018-01-02                                      Biotechnology
# ...                                                       ...
# 2018-03-07  Biotechnology, Health Care, Life Science, Medi...
# 2018-03-08  Finance, FinTech, Payments, Property Developme...
# 2018-03-08                              Health Care, Hospital
# 2018-03-08                             Food and Beverage, Tea
# 2018-03-09                     Fitness, Health Care, Wellness
#
#                                Stage  Amount($)  \
# Date
# 2018-01-01                      Seed    5800000
# 2018-01-01                      Seed     500000
# 2018-01-01                      Seed  135000000
# 2018-01-01                  Series A    4200000
# 2018-01-02                  Series A    3600000
# ...                              ...        ...
# 2018-03-07                      Seed    5800000
# 2018-03-08  Venture - Series Unknown    5800000
# 2018-03-08  Venture - Series Unknown    5800000
# 2018-03-08                      Seed   20000000
# 2018-03-09                      Seed    1000000
#
#                                  HeadQuarter  Year Founded
# Date
# 2018-01-01        Mumbai, Maharashtra, India  2018     NaN
# 2018-01-01           New Delhi, Delhi, India  2018     NaN
# 2018-01-01        Mumbai, Maharashtra, India  2018     NaN
# 2018-01-01       Bengaluru, Karnataka, India  2018     NaN
# 2018-01-02       Bengaluru, Karnataka, India  2018     NaN
# ...                                      ...   ...     ...
# 2018-03-07  Hyderabad, Andhra Pradesh, India  2018     NaN
# 2018-03-08         Ahmedabad, Gujarat, India  2018     NaN
# 2018-03-08     Chandigarh, Chandigarh, India  2018     NaN
# 2018-03-08        Chennai, Tamil Nadu, India  2018     NaN
# 2018-03-09        Mumbai, Maharashtra, India  2018     NaN
#
# [100 rows x 7 columns]

# %% [markdown]
# ## Replacing missing values in stage & Founded col / filtering headquater col / filtering the sector col by closing them in related col by using str.contain

# %%
valid_stages = ['Venture - Series Unknown','Seed', 'Angel', 'Series A', 'Series B', 'Pre-Seed', 'Grant', 'Series H', 
                'Series A', 'Series C', 'Series E', 'Corporate Round','Series D']

ind_2018.loc[~ind_2018['Stage'].isin(valid_stages), 'Stage'] = np.nan

# %%
mode_value = ind_2018['Stage'].mode()[0]
print(mode_value)
# Out:
# Seed

# %%
ind_2018['Stage'] = ind_2018['Stage'].fillna(ind_2018['Stage'].mode()[0])
ind_2018['Founded'] = ind_2018['Founded'].replace('NaN', np.nan)

# %%
ind_2018.head(100)
# Out:
#                               Company/Brand  \
# Date
# 2018-01-01  Hashtag Loyalty Private Limited
# 2018-01-01                        Simulanis
# 2018-01-01     Wellthy Therapeutics Pvt Ltd
# 2018-01-01                            mfine
# 2018-01-02            Pandorum Technologies
# ...                                     ...
# 2018-03-07         Theranosis Life Sciences
# 2018-03-08                         Billdesk
# 2018-03-08                        RAHI Care
# 2018-03-08                       Chai Kings
# 2018-03-09                     HealthAssure
#
#                                                        Sector  \
# Date
# 2018-01-01  Analytics, CRM, Loyalty Programs, Machine Lear...
# 2018-01-01                                           Training
# 2018-01-01                              Health Care, Hospital
# 2018-01-01                              Health Care, Hospital
# 2018-01-02                                      Biotechnology
# ...                                                       ...
# 2018-03-07  Biotechnology, Health Care, Life Science, Medi...
# 2018-03-08  Finance, FinTech, Payments, Property Developme...
# 2018-03-08                              Health Care, Hospital
# 2018-03-08                             Food and Beverage, Tea
# 2018-03-09                     Fitness, Health Care, Wellness
#
#                                Stage  Amount($)  \
# Date
# 2018-01-01                      Seed    5800000
# 2018-01-01                      Seed     500000
# 2018-01-01                      Seed  135000000
# 2018-01-01                  Series A    4200000
# 2018-01-02                  Series A    3600000
# ...                              ...        ...
# 2018-03-07                      Seed    5800000
# 2018-03-08  Venture - Series Unknown    5800000
# 2018-03-08  Venture - Series Unknown    5800000
# 2018-03-08                      Seed   20000000
# 2018-03-09                      Seed    1000000
#
#                                  HeadQuarter  Year  Founded
# Date
# 2018-01-01        Mumbai, Maharashtra, India  2018      NaN
# 2018-01-01           New Delhi, Delhi, India  2018      NaN
# 2018-01-01        Mumbai, Maharashtra, India  2018      NaN
# 2018-01-01       Bengaluru, Karnataka, India  2018      NaN
# 2018-01-02       Bengaluru, Karnataka, India  2018      NaN
# ...                                      ...   ...      ...
# 2018-03-07  Hyderabad, Andhra Pradesh, India  2018      NaN
# 2018-03-08         Ahmedabad, Gujarat, India  2018      NaN
# 2018-03-08     Chandigarh, Chandigarh, India  2018      NaN
# 2018-03-08        Chennai, Tamil Nadu, India  2018      NaN
# 2018-03-09        Mumbai, Maharashtra, India  2018      NaN
#
# [100 rows x 7 columns]

# %%
ind_2018.isna().sum()
# Out:
# Company/Brand      0
# Sector             0
# Stage              0
# Amount($)          0
# HeadQuarter        0
# Year               0
# Founded          526
# dtype: int64

# %%
# Split the Headquarters column by comma, and keep only the first value
ind_2018["City"] = ind_2018["HeadQuarter"].apply(lambda x: x.split(",")[0])

# %%
ind_2018.head()
# Out:
#                               Company/Brand  \
# Date
# 2018-01-01  Hashtag Loyalty Private Limited
# 2018-01-01                        Simulanis
# 2018-01-01     Wellthy Therapeutics Pvt Ltd
# 2018-01-01                            mfine
# 2018-01-02            Pandorum Technologies
#
#                                                        Sector     Stage  \
# Date
# 2018-01-01  Analytics, CRM, Loyalty Programs, Machine Lear...      Seed
# 2018-01-01                                           Training      Seed
# 2018-01-01                              Health Care, Hospital      Seed
# 2018-01-01                              Health Care, Hospital  Series A
# 2018-01-02                                      Biotechnology  Series A
#
#             Amount($)                  HeadQuarter  Year  Founded       City
# Date
# 2018-01-01    5800000   Mumbai, Maharashtra, India  2018      NaN     Mumbai
# 2018-01-01     500000      New Delhi, Delhi, India  2018      NaN  New Delhi
# 2018-01-01  135000000   Mumbai, Maharashtra, India  2018      NaN     Mumbai
# 2018-01-01    4200000  Bengaluru, Karnataka, India  2018      NaN  Bengaluru
# 2018-01-02    3600000  Bengaluru, Karnataka, India  2018      NaN  Bengaluru

# %%
ind_2018.drop('HeadQuarter',axis=1,inplace=True)

# %%
ind_2018 = ind_2018.rename(columns={'City': 'HeadQuarter'})

# %%
ind_2018.isna().sum()
# Out:
# Company/Brand      0
# Sector             0
# Stage              0
# Amount($)          0
# Year               0
# Founded          526
# HeadQuarter        0
# dtype: int64

# %%
tech = ['Mobile','Technology', 'Internet', 'Software', 'Hardware','SaaS','Blockchain','Apps','Information Services','SEM',
        'Artificial Intelligence','CleanTech','Aerospace','Robotics','Ai','PaaS','Medtech','Agritech','HR tech',
       'Tech','FoodTech','Safety tech','IoT','Legal tech','Infratech','Netwokring platform','Telecommunication','Cloud','Aero',
       'Virtual','Content','Photonics','app','Proptech','Deeptech','AR','VR','Agri tech','-Tech','AgriTech','IT','Network',
        'Data','HrTech','Foodtech','Spacetech','E-mobility','Automation','Logitech','HRTech','Drone','MLOps','Innovation',
       'BioTechnology','TaaS','network','equipment','SpaceTech','CRM','MarTech','Nanotechnology','Femtech','startup','AI']
fin = ['Lending','Finance','Insurance', 'Payments','Financial Services','Credit','Credit Cards','Mutual Funds',
       'Banking','Escrow','Venture','financial','Taxation','Capital','firm','Equity']
fint = ['NFT','Virtual Banking','FinTech','Fintech','Cryptocurrency','Crypto','Insurtech','InsurTech']
health = ['Health', 'Medical','Pharmaceutical','Health Diagnotics','Health Care','Hospital','Biotechnology','Biopharma',
         'Hygiene management','HealthTech','Healthcare','HealthCare','laboratory','Biotech','Healthtech','HeathTech',
         'Helathcare','Veterinary']
mkt = ['Brand Marketing','Marketing','Event Promotion','Market']
agric = ['Farming','Agriculture','Nutrition','Hauz Khas','Fishery']
con = ['Food','Food and Beverages','Dairy','Beverages','Beer','FMCG']
econ = ['B2B','Shopping','E-Commerce','Trading Platform','E-commerce','E-marketplace','marketplace','e-commerce','Ecommerce',
        'E-market','Commerce','Trading platform']
cons = ['Wholesale','Consumer','Shoes','Packaging','Retail','Consulting','Food Delivery']
edu = ['E-Learning','EdTech','Education','Communities','Edtech','Preschool','School']
welln = ['Lifestyle','Beauty','Wellness','Cosmetics','Yoga','Skincare','D2C','Fitness','Lifestyle','Training']
real_est=['Real Estate','Home Decor','Accomodation','Interior design','Home Design','Home interior','Co-living',
          'Construction']
log = ['Logistics','Rental','Tourism','Travel','TravelTech','Transport','Transportation','Aviation','Mobility']

auto = ['Automotive','Electric vehicle','Industrial Automation','Vehicles','Automotive tech','Automobile','Tyre','car','Car',
       'Vehicle','Mechanical']
manu = ['Manufacturing']
ener = ['Renewable Energy','Solar','Energy','Energy Storage','Battery','Oil and Gas','Renewable','EV','Electricity',
       'purification','Renewables']
medi = ['Entertainment','Media','News','Video','Digital Media','FM','Publication','OTT','Social Network','Music',
        'Digital platform','Podcast','publishing','Blogging']
game = ['Gaming','Games','Sports']

style = ['Fashion','Jewelry','Eyeglasses','Eye Wear','Apparel','Dating','Celebrity','Eyewear','D2C Fashion','Matrimony',
         'Textiles','D2C jewellery','Foootwear','Arts']
hos =['Hospitality','Hotel','Leisure']



ind_2018['Sector_clean'] = 'Other'
ind_2018.loc[ind_2018['Sector'].str.contains('|'.join(tech)), 'Sector_clean'] = 'Technology'
ind_2018.loc[ind_2018['Sector'].str.contains('|'.join(fin)), 'Sector_clean'] = 'Finance'
ind_2018.loc[ind_2018['Sector'].str.contains('|'.join(health)), 'Sector_clean'] = 'Healthcare'
ind_2018.loc[ind_2018['Sector'].str.contains('|'.join(mkt)), 'Sector_clean'] = 'Marketing'
ind_2018.loc[ind_2018['Sector'].str.contains('|'.join(agric)), 'Sector_clean'] = 'Agriculture'
ind_2018.loc[ind_2018['Sector'].str.contains('|'.join(econ)), 'Sector_clean'] = 'E-Commerce'
ind_2018.loc[ind_2018['Sector'].str.contains('|'.join(edu)), 'Sector_clean'] = 'Education'
ind_2018.loc[ind_2018['Sector'].str.contains('|'.join(welln)), 'Sector_clean'] = 'Wellness/Beauty'
ind_2018.loc[ind_2018['Sector'].str.contains('|'.join(real_est)), 'Sector_clean'] = 'Real Estate'
ind_2018.loc[ind_2018['Sector'].str.contains('|'.join(log)), 'Sector_clean'] = 'Logistics'

ind_2018.loc[ind_2018['Sector'].str.contains('|'.join(auto)), 'Sector_clean'] = 'Automotive'
ind_2018.loc[ind_2018['Sector'].str.contains('|'.join(manu)), 'Sector_clean'] = 'Manufacture'
ind_2018.loc[ind_2018['Sector'].str.contains('|'.join(ener)), 'Sector_clean'] = 'Energy'
ind_2018.loc[ind_2018['Sector'].str.contains('|'.join(medi)), 'Sector_clean'] = 'Media/Entertainment'
ind_2018.loc[ind_2018['Sector'].str.contains('|'.join(hos)), 'Sector_clean'] = 'Hospitality'
ind_2018.loc[ind_2018['Sector'].str.contains('|'.join(style)), 'Sector_clean'] = 'Lifestyle'
ind_2018.loc[ind_2018['Sector'].str.contains('|'.join(cons)), 'Sector_clean'] = 'Consumer Services'
ind_2018.loc[ind_2018['Sector'].str.contains('|'.join(game)), 'Sector_clean'] = 'Gaming'
ind_2018.loc[ind_2018['Sector'].str.contains('|'.join(fint)), 'Sector_clean'] = 'FinTech'
ind_2018.loc[ind_2018['Sector'].str.contains('|'.join(con)), 'Sector_clean'] = 'Consumables'

# %%
ind_2018.drop('Sector',axis=1,inplace=True)

# %%
ind_2018= ind_2018.rename(columns={'Sector_clean': 'Sector'})

# %%
ind_2018.head()
# Out:
#                               Company/Brand     Stage  Amount($)  Year  \
# Date
# 2018-01-01  Hashtag Loyalty Private Limited      Seed    5800000  2018
# 2018-01-01                        Simulanis      Seed     500000  2018
# 2018-01-01     Wellthy Therapeutics Pvt Ltd      Seed  135000000  2018
# 2018-01-01                            mfine  Series A    4200000  2018
# 2018-01-02            Pandorum Technologies  Series A    3600000  2018
#
#             Founded HeadQuarter             Sector
# Date
# 2018-01-01      NaN      Mumbai  Consumer Services
# 2018-01-01      NaN   New Delhi    Wellness/Beauty
# 2018-01-01      NaN      Mumbai         Automotive
# 2018-01-01      NaN   Bengaluru         Automotive
# 2018-01-02      NaN   Bengaluru         Healthcare

# %%
import seaborn as sns

# Plot a line chart of funding amounts over time
funding_over_time = ind_2018.groupby('Date')['Amount($)'].sum().reset_index()
sns.lineplot(data=funding_over_time, x='Date', y='Amount($)')
plt.show()

# %%
if ind_2018.empty:
    print("No data found for the year 2018")
else:
    # Calculate the total funding by sector
    total_funding_by_sector = ind_2018.groupby('Sector')['Amount($)'].sum().reset_index()

    top_10_sectors = total_funding_by_sector.sort_values(by='Amount($)', ascending=False).head(10)

    ax = sns.barplot(data=top_10_sectors, x='Sector', y='Amount($)')
    ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
    plt.show()

# %% [markdown]
# ## Accessing the shape of the data, Filling the missing the val with statistical means,Dropping columns,Creating a date series

# %%
ind_2019.head()
# Out:
#     Company/Brand  Founded HeadQuarter           Sector  \
# 0  Bombay Shaving      NaN         NaN        Ecommerce
# 1       Ruangguru   2014.0      Mumbai           Edtech
# 2        Eduisfun      NaN      Mumbai           Edtech
# 3        HomeLane   2014.0     Chennai  Interior design
# 4        Nu Genes   2004.0   Telangana         AgriTech
#
#                                         What it does  \
# 0         Provides a range of male grooming products
# 1  A learning platform that provides topic-based ...
# 2            It aims to make learning fun via games.
# 3              Provides interior designing solutions
# 4  It is a seed company engaged in production, pr...
#
#                                 Founders  \
# 0                     Shantanu Deshpande
# 1  Adamas Belva Syah Devara, Iman Usman.
# 2                          Jatin Solanki
# 3           Srikanth Iyer, Rama Harinath
# 4                 Narayana Reddy Punyala
#
#                                             Investor     Amount($)  \
# 0                               Sixth Sense Ventures    $6,300,000
# 1                                   General Atlantic  $150,000,000
# 2     Deepak Parekh, Amitabh Bachchan, Piyush Pandey   $28,000,000
# 3  Evolvence India Fund (EIF), Pidilite Group, FJ...   $30,000,000
# 4           Innovation in Food and Agriculture (IFA)    $6,000,000
#
#            Stage
# 0            NaN
# 1       Series C
# 2  Fresh funding
# 3       Series D
# 4            NaN

# %%
ind_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89 entries, 0 to 88
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company/Brand  89 non-null     object
#  1   Founded        60 non-null     float64
#  2   HeadQuarter    70 non-null     object
#  3   Sector         84 non-null     object
#  4   What it does   89 non-null     object
#  5   Founders       86 non-null     object
#  6   Investor       89 non-null     object
#  7   Amount($)      89 non-null     object
#  8   Stage          43 non-null     object
# dtypes: float64(1), object(8)
# memory usage: 6.4+ KB

# %%
ind_2019.describe()
# Out:
#            Founded
# count    60.000000
# mean   2014.533333
# std       2.937003
# min    2004.000000
# 25%    2013.000000
# 50%    2015.000000
# 75%    2016.250000
# max    2019.000000

# %%
ind_2019.isna().sum()
# Out:
# Company/Brand     0
# Founded          29
# HeadQuarter      19
# Sector            5
# What it does      0
# Founders          3
# Investor          0
# Amount($)         0
# Stage            46
# dtype: int64

# %%
ind_2019.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 84    False
# 85    False
# 86    False
# 87    False
# 88    False
# Length: 89, dtype: bool

# %%
ind_2019['Sector'].replace('—', pd.np.nan, inplace=True)

ind_2019['Year']=2019
# Out:
# C:\Users\GILBERT\AppData\Local\Temp\ipykernel_13168\4162604990.py:1: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead.
#   ind_2019['Sector'].replace('—', pd.np.nan, inplace=True)

# %%
ind_2019.isna().sum()
# Out:
# Company/Brand     0
# Founded          29
# HeadQuarter      19
# Sector            5
# What it does      0
# Founders          3
# Investor          0
# Amount($)         0
# Stage            46
# Year              0
# dtype: int64

# %%
ind_2019.loc[41, 'Sector'] = 'Media'
ind_2019.loc[49, 'Sector'] = 'Human Resources'
ind_2019.loc[52, 'Sector'] = 'Technology'
ind_2019.loc[56, 'Sector'] = 'Technology'
ind_2019.loc[57, 'Sector'] = 'E-Commerce'

# %%
ind_2019.drop('What it does',axis=1,inplace=True)

# %%
# # create a DatetimeIndex with dates for the entire year
date_range = pd.date_range(start='2019-01-01', end='2019-12-31', freq='D')

# # create a new column 'Date' with random dates within the year 2018
ind_2019['Date'] = np.random.choice(date_range, size=len(ind_2019))

ind_2019 = ind_2019.sort_values('Date')

ind_2019['Date'] = pd.to_datetime(ind_2019['Date'], format='%Y-%m-%d')

# %%
ind_2019.set_index('Date',inplace=True)

# %%
mode_value = ind_2019['Founders'].mode()[0]
print(mode_value)

mode_value = ind_2019['HeadQuarter'].mode()[0]
print(mode_value)

mode_value = ind_2019['Stage'].mode()[0]
print(mode_value)
# Out:
# Vivek Gupta, Abhay Hanjura
# Bangalore
# Series A

# %%
ind_2019['HeadQuarter'] = ind_2019['HeadQuarter'].fillna(ind_2019['HeadQuarter'].mode()[0])
ind_2019['Stage'] = ind_2019['Stage'].fillna(ind_2019['Stage'].mode()[0])
ind_2019['Founders'] = ind_2019['Founders'].fillna(ind_2019['Founders'].mode()[0])

# %% [markdown]
# ## Using Statiscal means to fill the missing values in the founded column

# %%
ind_2019['Founded'] = pd.to_numeric(ind_2019['Founded'], errors='coerce')

# %%
ind_2019['Founded'] = ind_2019['Founded'].fillna(0)

# %%
plt.hist(ind_2019['Founded'], bins=20)
plt.title('Distribution of Year')
plt.xlabel('Founded')
plt.ylabel('Frequency')
plt.show()

# %%
ind_2019['Founded'].replace(0, np.nan, inplace=True)

# %%
ind_2019.isna().sum()
# Out:
# Company/Brand     0
# Founded          29
# HeadQuarter       0
# Sector            0
# Founders          0
# Investor          0
# Amount($)         0
# Stage             0
# Year              0
# dtype: int64

# %%
ind_2019['Founded'].fillna(ind_2019['Founded'].median(), inplace=True)

# %%
ind_2019['Founded'] = ind_2019['Founded'].astype(int)

# %% [markdown]
# ## Restructuring the shape of the column & using statistical means to fill them, Restructuring the name convention of the sector column by containing it in a list of substrings and assigning it to name.

# %%
ind_2019['Amount($)'].replace('', pd.np.nan, inplace=True)
# Out:
# C:\Users\GILBERT\AppData\Local\Temp\ipykernel_13168\1514532099.py:1: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead.
#   ind_2019['Amount($)'].replace('', pd.np.nan, inplace=True)

# %%
ind_2019['Amount($)'] = ind_2019['Amount($)'].str.replace('[^\d\.]', '')
# Out:
# C:\Users\GILBERT\AppData\Local\Temp\ipykernel_13168\661071711.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   ind_2019['Amount($)'] = ind_2019['Amount($)'].str.replace('[^\d\.]', '')

# %%
ind_2019['Amount($)'] = pd.to_numeric(ind_2019['Amount($)'])
ind_2019['Amount($)'] = pd.to_numeric(ind_2019['Amount($)'])

# %%
ind_2019.head()
# Out:
#            Company/Brand  Founded HeadQuarter         Sector  \
# Date
# 2019-01-10       Licious     2015   Bangalore           Food
# 2019-01-11  Ecom Express     2012    Gurugram      Logistics
# 2019-01-13       Zetwerk     2018   Bangalore  Manufacturing
# 2019-01-14           Oyo     2013    Gurugram    Hospitality
# 2019-01-18       Moms Co     2015   New Delhi     E-commerce
#
#                                                      Founders  \
# Date
# 2019-01-10                         Vivek Gupta, Abhay Hanjura
# 2019-01-11  Krishnan, Manju Dhawan, K Satyanarayana, Sanje...
# 2019-01-13                Amit Acharya, Srinath Ramakkrushnan
# 2019-01-14                                     Ritesh Agarwal
# 2019-01-18                                      Malika Sadani
#
#                                                      Investor    Amount($)  \
# Date
# 2019-01-10                                    Vertex Ventures   25000000.0
# 2019-01-11                                          CDC Group   36000000.0
# 2019-01-13  Lightspeed and Greenoaks Capital, Sequoia Indi...   32000000.0
# 2019-01-14  MyPreferred Transformation, Avendus Finance, S...  693000000.0
# 2019-01-18               Saama Capital, DSG Consumer Partners    5000000.0
#
#                Stage  Year
# Date
# 2019-01-10  Series D  2019
# 2019-01-11  Series A  2019
# 2019-01-13  Series B  2019
# 2019-01-14  Series A  2019
# 2019-01-18  Series B  2019

# %%
ind_2019.isna().sum()
# Out:
# Company/Brand     0
# Founded           0
# HeadQuarter       0
# Sector            0
# Founders          0
# Investor          0
# Amount($)        12
# Stage             0
# Year              0
# dtype: int64

# %%
# Create a histogram of the 'Amount' column
plt.hist(ind_2019['Amount($)'], bins=20)
plt.title('Distribution of Amount')
plt.xlabel('Amount($)')
plt.ylabel('Frequency')
plt.show()

# %%
ind_2019['Amount($)'] = ind_2019['Amount($)'].fillna(ind_2019['Amount($)'].median())

# %%
ind_2019['Amount($)'] = ind_2019['Amount($)'].astype(int)

# %%
ind_2019.head()
# Out:
#            Company/Brand  Founded HeadQuarter         Sector  \
# Date
# 2019-01-10       Licious     2015   Bangalore           Food
# 2019-01-11  Ecom Express     2012    Gurugram      Logistics
# 2019-01-13       Zetwerk     2018   Bangalore  Manufacturing
# 2019-01-14           Oyo     2013    Gurugram    Hospitality
# 2019-01-18       Moms Co     2015   New Delhi     E-commerce
#
#                                                      Founders  \
# Date
# 2019-01-10                         Vivek Gupta, Abhay Hanjura
# 2019-01-11  Krishnan, Manju Dhawan, K Satyanarayana, Sanje...
# 2019-01-13                Amit Acharya, Srinath Ramakkrushnan
# 2019-01-14                                     Ritesh Agarwal
# 2019-01-18                                      Malika Sadani
#
#                                                      Investor  Amount($)  \
# Date
# 2019-01-10                                    Vertex Ventures   25000000
# 2019-01-11                                          CDC Group   36000000
# 2019-01-13  Lightspeed and Greenoaks Capital, Sequoia Indi...   32000000
# 2019-01-14  MyPreferred Transformation, Avendus Finance, S...  693000000
# 2019-01-18               Saama Capital, DSG Consumer Partners    5000000
#
#                Stage  Year
# Date
# 2019-01-10  Series D  2019
# 2019-01-11  Series A  2019
# 2019-01-13  Series B  2019
# 2019-01-14  Series A  2019
# 2019-01-18  Series B  2019

# %%
ind_2019.isna().sum()
# Out:
# Company/Brand    0
# Founded          0
# HeadQuarter      0
# Sector           0
# Founders         0
# Investor         0
# Amount($)        0
# Stage            0
# Year             0
# dtype: int64

# %%
# # Create a list of substrings to search for in the Sector column
tech = ['Mobile','Technology', 'Internet', 'Software', 'Hardware','SaaS','Blockchain','Apps','Information Services','SEM',
        'Artificial Intelligence','CleanTech','Aerospace','Robotics','Ai','PaaS','Medtech','Agritech','HR tech',
       'Tech','FoodTech','Safety tech','IoT','Legal tech','Infratech','Netwokring platform','Telecommunication','Cloud','Aero',
       'Virtual','Content','Photonics','app','Proptech','Deeptech','AR','VR','Agri tech','-Tech','AgriTech','IT','Network',
        'Data','HrTech','Foodtech','Spacetech','E-mobility','Automation','Logitech','HRTech','Drone','MLOps','Innovation',
       'BioTechnology','TaaS','network','equipment','SpaceTech','CRM','MarTech','Nanotechnology','Femtech','startup','AI']
fin = ['Lending','Finance','Insurance', 'Payments','Financial Services','Credit','Credit Cards','Mutual Funds',
       'Banking','Escrow','Venture','financial','Taxation','Capital','firm','Equity']
fint = ['NFT','Virtual Banking','FinTech','Fintech','Cryptocurrency','Crypto','Insurtech','InsurTech']
health = ['Health', 'Medical','Pharmaceutical','Health Diagnotics','Health Care','Hospital','Biotechnology','Biopharma',
         'Hygiene management','HealthTech','Healthcare','HealthCare','laboratory','Biotech','Healthtech','HeathTech',
         'Helathcare','Veterinary']
mkt = ['Brand Marketing','Marketing','Event Promotion','Market']
agric = ['Farming','Agriculture','Nutrition','Hauz Khas','Fishery']
con = ['Food','Food and Beverages','Dairy','Beverages','Beer','FMCG']
econ = ['B2B','Shopping','E-Commerce','Trading Platform','E-commerce','E-marketplace','marketplace','e-commerce','Ecommerce',
        'E-market','Commerce','Trading platform']
cons = ['Wholesale','Consumer','Shoes','Packaging','Retail','Consulting','Food Delivery']
edu = ['E-Learning','EdTech','Education','Communities','Edtech','Preschool','School']
welln = ['Lifestyle','Beauty','Wellness','Cosmetics','Yoga','Skincare','D2C','Fitness','Lifestyle','Training']
real_est=['Real Estate','Home Decor','Accomodation','Interior design','Home Design','Home interior','Co-living',
          'Construction']
log = ['Logistics','Rental','Tourism','Travel','TravelTech','Transport','Transportation','Aviation','Mobility']

auto = ['Automotive','Electric vehicle','Industrial Automation','Vehicles','Automotive tech','Automobile','Tyre','car','Car',
       'Vehicle','Mechanical']
manu = ['Manufacturing']
ener = ['Renewable Energy','Solar','Energy','Energy Storage','Battery','Oil and Gas','Renewable','EV','Electricity',
       'purification','Renewables']
medi = ['Entertainment','Media','News','Video','Digital Media','FM','Publication','OTT','Social Network','Music',
        'Digital platform','Podcast','publishing','Blogging']
game = ['Gaming','Games','Sports']

style = ['Fashion','Jewelry','Eyeglasses','Eye Wear','Apparel','Dating','Celebrity','Eyewear','D2C Fashion','Matrimony',
         'Textiles','D2C jewellery','Foootwear','Arts']
hos =['Hospitality','Hotel','Leisure']


ind_2019['Sector_clean'] = 'Other'
ind_2019.loc[ind_2019['Sector'].str.contains('|'.join(tech)), 'Sector_clean'] = 'Technology'
ind_2019.loc[ind_2019['Sector'].str.contains('|'.join(fin)), 'Sector_clean'] = 'Finance'
ind_2019.loc[ind_2019['Sector'].str.contains('|'.join(health)), 'Sector_clean'] = 'Healthcare'
ind_2019.loc[ind_2019['Sector'].str.contains('|'.join(mkt)), 'Sector_clean'] = 'Marketing'
ind_2019.loc[ind_2019['Sector'].str.contains('|'.join(agric)), 'Sector_clean'] = 'Agriculture'
ind_2019.loc[ind_2019['Sector'].str.contains('|'.join(econ)), 'Sector_clean'] = 'E-Commerce'
ind_2019.loc[ind_2019['Sector'].str.contains('|'.join(edu)), 'Sector_clean'] = 'Education'
ind_2019.loc[ind_2019['Sector'].str.contains('|'.join(welln)), 'Sector_clean'] = 'Wellness/Beauty'
ind_2019.loc[ind_2019['Sector'].str.contains('|'.join(real_est)), 'Sector_clean'] = 'Real Estate'
ind_2019.loc[ind_2019['Sector'].str.contains('|'.join(log)), 'Sector_clean'] = 'Logistics'

ind_2019.loc[ind_2019['Sector'].str.contains('|'.join(auto)), 'Sector_clean'] = 'Automotive'
ind_2019.loc[ind_2019['Sector'].str.contains('|'.join(manu)), 'Sector_clean'] = 'Manufacture'
ind_2019.loc[ind_2019['Sector'].str.contains('|'.join(ener)), 'Sector_clean'] = 'Energy'
ind_2019.loc[ind_2019['Sector'].str.contains('|'.join(medi)), 'Sector_clean'] = 'Media/Entertainment'
ind_2019.loc[ind_2019['Sector'].str.contains('|'.join(hos)), 'Sector_clean'] = 'Hospitality'
ind_2019.loc[ind_2019['Sector'].str.contains('|'.join(style)), 'Sector_clean'] = 'Lifestyle'
ind_2019.loc[ind_2019['Sector'].str.contains('|'.join(cons)), 'Sector_clean'] = 'Consumer Services'
ind_2019.loc[ind_2019['Sector'].str.contains('|'.join(game)), 'Sector_clean'] = 'Gaming'
ind_2019.loc[ind_2019['Sector'].str.contains('|'.join(fint)), 'Sector_clean'] = 'FinTech'
ind_2019.loc[ind_2019['Sector'].str.contains('|'.join(con)), 'Sector_clean'] = 'Consumables'

# %%
ind_2019.drop('Sector',axis=1,inplace=True)

# %%
ind_2019= ind_2019.rename(columns={'Sector_clean': 'Sector'})

# %%
ind_2019.head(50)
# Out:
#                            Company/Brand  Founded    HeadQuarter  \
# Date
# 2019-01-10                       Licious     2015      Bangalore
# 2019-01-11                  Ecom Express     2012       Gurugram
# 2019-01-13                       Zetwerk     2018      Bangalore
# 2019-01-14                           Oyo     2013       Gurugram
# 2019-01-18                       Moms Co     2015      New Delhi
# 2019-01-23                       Cuemath     2013      Bangalore
# 2019-01-24                   Open Secret     2015      Bangalore
# 2019-01-29                          Zebu     2015      Bangalore
# 2019-01-31                       Medlife     2014      Bangalore
# 2019-02-03                        Ecozen     2015           Pune
# 2019-02-05                      Nu Genes     2004      Telangana
# 2019-02-08                  Euler Motors     2015          Delhi
# 2019-02-09                         Sarva     2015        Chennai
# 2019-02-10                     HungerBox     2015      Bangalore
# 2019-02-10                 Fireflies .ai     2015      Bangalore
# 2019-02-16                    MyGameMate     2015      Bangalore
# 2019-02-17                Bombay Shaving     2015      Bangalore
# 2019-02-18                     Ninjacart     2015      Bangalore
# 2019-03-01                      CarDekho     2008         Jaipur
# 2019-03-01                      Kratikal     2015  Uttar pradesh
# 2019-03-02                   Springboard     2013      Bangalore
# 2019-03-05                     Ruangguru     2014         Mumbai
# 2019-03-14                      HomeLane     2014        Chennai
# 2019-03-15                    Kaleidofin     2018        Chennai
# 2019-03-23                      Appnomic     2015      Bangalore
# 2019-04-02                       Witblox     2014      Bangalore
# 2019-04-03                      Pumpkart     2014     Chandigarh
# 2019-04-05                   Freshokartz     2016         Jaipur
# 2019-04-08                    SalaryFits     2015      Bangalore
# 2019-04-14                      Eduisfun     2015         Mumbai
# 2019-04-16                  Pristyn Care     2018      Bangalore
# 2019-04-17                     Zolostays     2015      Bangalore
# 2019-04-17             Asteria Aerospace     2011      Bangalore
# 2019-04-19                       Licious     2015      Bangalore
# 2019-04-22                     Shadowfax     2015      Bangalore
# 2019-04-29            DROR Labs Pvt. Ltd     2018          Delhi
# 2019-05-02                 Stanza Living     2017          Delhi
# 2019-05-08                         truMe     2015      Bangalore
# 2019-05-09               Smart Institute     2015          Surat
# 2019-05-18                      Lawyered     2015          Delhi
# 2019-05-21                    Rein Games     2015          Noida
# 2019-05-22                        Rivigo     2014      Bangalore
# 2019-06-03                     Quantiphi     2015      Bangalore
# 2019-06-09                       Froogal     2015      Hyderabad
# 2019-06-11  Lil’ Goodness and sCool meal     2015      Bangalore
# 2019-06-12                     JobSquare     2019      Ahmedabad
# 2019-06-13                   HappyEasyGo     2017       Gurugram
# 2019-06-17                     WishADish     2015          Delhi
# 2019-06-21                       m.Paani     2015         Mumbai
# 2019-06-22                      IndyFint     2019      Bangalore
#
#                                                      Founders  \
# Date
# 2019-01-10                         Vivek Gupta, Abhay Hanjura
# 2019-01-11  Krishnan, Manju Dhawan, K Satyanarayana, Sanje...
# 2019-01-13                Amit Acharya, Srinath Ramakkrushnan
# 2019-01-14                                     Ritesh Agarwal
# 2019-01-18                                      Malika Sadani
# 2019-01-23                                       Manan Khurma
# 2019-01-24                        Ahana Gautam, Udit Kejriwal
# 2019-01-29         Team of Waterloo-based software developers
# 2019-01-31                       Tushar Kumar, Prashant Singh
# 2019-02-03      Devendra Gupta, Prateek Singhal, Vivek Pandey
# 2019-02-05                             Narayana Reddy Punyala
# 2019-02-08                                       Saurav Kumar
# 2019-02-09                                     Sarvesh Shashi
# 2019-02-10                        Sandipan Mitra, Uttam Kumar
# 2019-02-10                                        Sam Udotong
# 2019-02-16                       Parshavv Jain& Raju Kushwaha
# 2019-02-17                                 Shantanu Deshpande
# 2019-02-18   Thirukumaran Nagarajanin, Vasudevan Chinnathambi
# 2019-03-01                                          Amit Jain
# 2019-03-01                                     Pavan Kushwaha
# 2019-03-02                         Gautam Tambay, Parul Gupta
# 2019-03-05              Adamas Belva Syah Devara, Iman Usman.
# 2019-03-14                       Srikanth Iyer, Rama Harinath
# 2019-03-15                  Puneet Gupta, Sucharita Mukherjee
# 2019-03-23                                      D Padmanabhan
# 2019-04-02                                          Amit Modi
# 2019-04-03                                          KS Bhatia
# 2019-04-05                                      Rajendra Lora
# 2019-04-08                                      Renato Araujo
# 2019-04-14                                      Jatin Solanki
# 2019-04-16  Harsimarbir Singh, Dr Vaibhav Kapoor, Dr Garim...
# 2019-04-17          Akhil Sikri, Nikhil Sikri, Sneha Choudhry
# 2019-04-17                           Neel Mehta, Nihar Vartak
# 2019-04-19                         Vivek Gupta, Abhay Hanjura
# 2019-04-22                Abhishek Bansal, Vaibhav Khandelwal
# 2019-04-29                     Dhiraj Naubhar, Dheeraj Bansal
# 2019-05-02                      Sandeep Dalmia, Anindya Dutta
# 2019-05-08             Babu Dayal, Pramod Uniyal, Lalit Mehta
# 2019-05-09                         Vivek Gupta, Abhay Hanjura
# 2019-05-18                      Ashish Bhatia, Himanshu Gupta
# 2019-05-21  Vaibhav Gupta, Himanshu Devra, Pranav Chaudhar...
# 2019-05-22                           Deepak Garg, Gazal Kalra
# 2019-06-03                                     Renuka Ramnath
# 2019-06-09                Jeevan Chowdary M, Harshit Harchani
# 2019-06-11                         Vivek Gupta, Abhay Hanjura
# 2019-06-12                                       Ishit Jethwa
# 2019-06-13                         Vivek Prabhakar, Boris Zha
# 2019-06-17                      Sawan Kumar, Bhavya Bhambhani
# 2019-06-21                                    Akanksha Hazari
# 2019-06-22                                  Paddy Padmanabhan
#
#                                                      Investor  Amount($)  \
# Date
# 2019-01-10                                    Vertex Ventures   25000000
# 2019-01-11                                          CDC Group   36000000
# 2019-01-13  Lightspeed and Greenoaks Capital, Sequoia Indi...   32000000
# 2019-01-14  MyPreferred Transformation, Avendus Finance, S...  693000000
# 2019-01-18               Saama Capital, DSG Consumer Partners    5000000
# 2019-01-23  Manta Ray Ventures Limited, Google’s Capital G...    5500000
# 2019-01-24                                    Matrix Partners    6000000
# 2019-01-29                                        Undisclosed    4000000
# 2019-01-31                   Wilson Global Opportunities Fund   15500000
# 2019-02-03   Innovation in Food & Agriculture Fund (IFA Fund)    6000000
# 2019-02-05           Innovation in Food and Agriculture (IFA)    6000000
# 2019-02-08                  Blume Ventures, Emergent Ventures    2000000
# 2019-02-09                   Venture fund, Fireside Ventures.    2800000
# 2019-02-10  Paytm, Asian VC fund NPTK, Sabre Partners, Neo...   12000000
# 2019-02-10                                    Canaan Partners    5000000
# 2019-02-16                               Jindagi Live Angels,     100000
# 2019-02-17                               Sixth Sense Ventures    6300000
# 2019-02-18                                  Walmart, Flipkart    6000000
# 2019-03-01  Ping An Global Voyager Fund, Hillhouse Capital...   70000000
# 2019-03-01          Gilda VC, Art Venture, Rajeev Chitrabhanu    1000000
# 2019-03-02                                      Reach Capital   11000000
# 2019-03-05                                   General Atlantic  150000000
# 2019-03-14  Evolvence India Fund (EIF), Pidilite Group, FJ...   30000000
# 2019-03-15                                         Oikocredit    5000000
# 2019-03-23                                   Avataar Ventures   22000000
# 2019-04-02                              Mumbai Angels Network     182700
# 2019-04-03                                         Dinesh Dua    6000000
# 2019-04-05                                           ThinkLab     150000
# 2019-04-08                        Brazilian VC Fund Confrapar    5000000
# 2019-04-14     Deepak Parekh, Amitabh Bachchan, Piyush Pandey   28000000
# 2019-04-16  Sequoia India, Hummingbird Ventures, Greenoaks...   12000000
# 2019-04-17                                   Trifecta Capital    7000000
# 2019-04-17                                Reliance Industries  230000000
# 2019-04-19                                 Vertex Growth Fund   30000000
# 2019-04-22  Flipkart, Eight Roads Ventures, NGP Capital, Q...   60000000
# 2019-04-29                          Inflection Point Ventures    6000000
# 2019-05-02                                    Alteria Capital    5700000
# 2019-05-08                                      Rajan Kaistha     140000
# 2019-05-09                                      HNI investors    1500000
# 2019-05-18  Pramendra Tomar, Ratish Pandey, Munish Bhatia,...     100000
# 2019-05-21  Manipal Education and Medical Group (MEMG) fam...   50000000
# 2019-05-22  SAIF Partners India VI Ltd, Spring Canter Inve...   20000000
# 2019-06-03               Multiples Alternate Asset Management   20000000
# 2019-06-09                           US-based angel investors    1000000
# 2019-06-11                      Sajan Pillai, Muthu Krishnan,     400000
# 2019-06-12                                      Titan Capital     140500
# 2019-06-13  Korea Investment Partners (KIP), Samsung Ventu...   49400000
# 2019-06-17                                        Undisclosed    6000000
# 2019-06-21                                AC Ventures, Henkel    5500000
# 2019-06-22                                Saravanan Adiseshan    2100000
#
#                     Stage  Year           Sector
# Date
# 2019-01-10       Series D  2019      Consumables
# 2019-01-11       Series A  2019        Logistics
# 2019-01-13       Series B  2019      Manufacture
# 2019-01-14       Series A  2019      Hospitality
# 2019-01-18       Series B  2019       E-Commerce
# 2019-01-23       Series A  2019        Education
# 2019-01-24       Series A  2019      Consumables
# 2019-01-29     Seed round  2019            Other
# 2019-01-31       Series A  2019       Healthcare
# 2019-02-03       Series A  2019       Technology
# 2019-02-05       Series A  2019       Technology
# 2019-02-08       Series A  2019       Automotive
# 2019-02-09       Series A  2019  Wellness/Beauty
# 2019-02-10       Series C  2019      Consumables
# 2019-02-10       Series A  2019       Technology
# 2019-02-16       Series A  2019           Gaming
# 2019-02-17       Series A  2019       E-Commerce
# 2019-02-18       Series A  2019       E-Commerce
# 2019-03-01       Series D  2019       Automotive
# 2019-03-01   Pre-series A  2019       Technology
# 2019-03-02  Post series A  2019        Education
# 2019-03-05       Series C  2019        Education
# 2019-03-14       Series D  2019      Real Estate
# 2019-03-15       Series A  2019          FinTech
# 2019-03-23       Series A  2019       Technology
# 2019-04-02       Series A  2019        Education
# 2019-04-03       Series A  2019       E-Commerce
# 2019-04-05   Pre series A  2019       E-Commerce
# 2019-04-08       Series A  2019          FinTech
# 2019-04-14  Fresh funding  2019        Education
# 2019-04-16       Series B  2019       Automotive
# 2019-04-17       Series A  2019      Real Estate
# 2019-04-17       Series A  2019       Technology
# 2019-04-19       Series E  2019      Consumables
# 2019-04-22       Series D  2019        Logistics
# 2019-04-29       Series A  2019       Technology
# 2019-05-02       Series A  2019      Real Estate
# 2019-05-08       Series A  2019       Technology
# 2019-05-09       Series A  2019        Education
# 2019-05-18       Series A  2019       Technology
# 2019-05-21   Pre series A  2019       Technology
# 2019-05-22       Series F  2019        Logistics
# 2019-06-03       Series A  2019       Technology
# 2019-06-09   Pre series A  2019        Marketing
# 2019-06-11       Series A  2019      Consumables
# 2019-06-12       Series A  2019       Technology
# 2019-06-13      Series B+  2019        Logistics
# 2019-06-17       Series A  2019      Consumables
# 2019-06-21       Series A  2019       E-Commerce
# 2019-06-22       Series A  2019          FinTech

# %%
if ind_2019.empty:
    print("No data found for the year 2018")
else:
    # Calculate the total funding by sector
    total_funding_by_sector = ind_2019.groupby('Sector')['Amount($)'].sum().reset_index()

    top_10_sectors = total_funding_by_sector.sort_values(by='Amount($)', ascending=False).head(10)

    ax = sns.barplot(data=top_10_sectors, x='Sector', y='Amount($)')
    ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
    plt.show()

# %% [markdown]
# ## Checking the shape of the data,Replace missing values and dropping,adding a date series

# %%
ind_2020.head()
# Out:
#   Company/Brand Founded HeadQuarter              Sector  \
# 0    Aqgromalin    2019     Chennai            AgriTech
# 1      Krayonnz    2019   Bangalore              EdTech
# 2  PadCare Labs    2018        Pune  Hygiene management
# 3         NCOME    2020   New Delhi              Escrow
# 4    Gramophone    2016      Indore            AgriTech
#
#                                         What it does  \
# 0                       Cultivating Ideas for Profit
# 1  An academy-guardian-scholar centric ecosystem ...
# 2   Converting bio-hazardous waste to harmless waste
# 3                       Escrow-as-a-service platform
# 4  Gramophone is an AgTech platform enabling acce...
#
#                                             Founders  \
# 0                    Prasanna Manogaran, Bharani C L
# 1                   Saurabh Dixit, Gurudutt Upadhyay
# 2                                    Ajinkya Dhariya
# 3                                      Ritesh Tiwari
# 4  Ashish Rajan Singh, Harshit Gupta, Nishant Mah...
#
#                               Investor    Amount($)     Stage Unnamed: 9
# 0                      Angel investors     $200,000       NaN        NaN
# 1                      GSF Accelerator     $100,000  Pre-seed        NaN
# 2                       Venture Center  Undisclosed  Pre-seed        NaN
# 3  Venture Catalysts, PointOne Capital     $400,000       NaN        NaN
# 4  Siana Capital Management, Info Edge     $340,000       NaN        NaN

# %%
ind_2020.describe()
# Out:
#        Company/Brand Founded HeadQuarter   Sector  \
# count           1055     843         961     1042
# unique           905      27          77      302
# top            Nykaa    2015   Bangalore  Fintech
# freq               6     136         317       80
#
#                             What it does       Founders           Investor  \
# count                               1055           1043               1017
# unique                               990            927                848
# top     Provides online learning classes  Falguni Nayar  Venture Catalysts
# freq                                   4              6                 20
#
#           Amount($)     Stage Unnamed: 9
# count          1052       591          2
# unique          309        42          2
# top     Undisclosed  Series A   Pre-Seed
# freq            243        96          1

# %%
ind_2020['Sector'].replace('—', pd.np.nan, inplace=True)

ind_2020['Year']=2020
# Out:
# C:\Users\GILBERT\AppData\Local\Temp\ipykernel_13168\1812708846.py:1: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead.
#   ind_2020['Sector'].replace('—', pd.np.nan, inplace=True)

# %%
ind_2020.isna().sum()
# Out:
# Company/Brand       0
# Founded           212
# HeadQuarter        94
# Sector             13
# What it does        0
# Founders           12
# Investor           38
# Amount($)           3
# Stage             464
# Unnamed: 9       1053
# Year                0
# dtype: int64

# %%
ind_2020.loc[518, 'Sector'] = 'E-Commerce'
ind_2020.loc[569, 'Sector'] = 'E-Commerce'
ind_2020.loc[687, 'Sector'] = 'Social Work'
ind_2020.loc[699, 'Sector'] = 'Beauty&Wellness'
ind_2020.loc[707, 'Sector'] = 'E-Commerce'
ind_2020.loc[732, 'Sector'] = 'Technology'
ind_2020.loc[746, 'Sector'] = 'E-Commerce'
ind_2020.loc[763, 'Sector'] = 'E-Commerce'
ind_2020.loc[746, 'Sector'] = 'E-Commerce'
ind_2020.loc[809, 'Sector'] = 'Technology'
ind_2020.loc[918, 'Sector'] = 'Fintech'
ind_2020.loc[926, 'Sector'] = 'Real Estate'
ind_2020.loc[1012, 'Sector'] = 'Technology'
ind_2020.loc[1031, 'Sector'] = 'Technology'
ind_2020.loc[746, 'Sector'] = 'E-Commerce'

# %%
ind_2020.isna().sum()
# Out:
# Company/Brand       0
# Founded           212
# HeadQuarter        94
# Sector              0
# What it does        0
# Founders           12
# Investor           38
# Amount($)           3
# Stage             464
# Unnamed: 9       1053
# Year                0
# dtype: int64

# %%
ind_2020.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1050    False
# 1051    False
# 1052    False
# 1053    False
# 1054    False
# Length: 1055, dtype: bool

# %%
ind_2020.drop_duplicates(inplace=True)

# %%
# create a DatetimeIndex with dates for the entire year
date_range = pd.date_range(start='2020-01-01', end='2020-12-31', freq='D')

# create a new column 'Date' with random dates within the year 2018
ind_2020['Date'] = np.random.choice(date_range, size=len(ind_2020))

ind_2020 = ind_2020.sort_values('Date')

ind_2020['Date'] = pd.to_datetime(ind_2020['Date'], format='%Y-%m-%d')

# %%
ind_2020.set_index('Date',inplace=True)

# %%
mode_value = ind_2020['Founders'].mode()[0]
print(mode_value)

mode_value = ind_2020['Stage'].mode()[0]
print(mode_value)

mode_value = ind_2020['Investor'].mode()[0]
print(mode_value)

mode_value = ind_2020['HeadQuarter'].mode()[0]
print(mode_value)
# Out:
# Byju Raveendran
# Series A
# Venture Catalysts
# Bangalore

# %%
ind_2020['Founders'] = ind_2020['Founders'].fillna(ind_2020['Founders'].mode()[0])
ind_2020['Stage'] = ind_2020['Stage'].fillna(ind_2020['Stage'].mode()[0])
ind_2020['Investor'] = ind_2020['Investor'].fillna(ind_2020['Investor'].mode()[0])
ind_2020['HeadQuarter'] = ind_2020['HeadQuarter'].fillna(ind_2020['HeadQuarter'].mode()[0])

# %%
ind_2020['Founded'] = pd.to_numeric(ind_2020['Founded'], errors='coerce')

ind_2020['Founded'] = ind_2020['Founded'].fillna(0)

# %%
plt.hist(ind_2020['Founded'], bins=20)
plt.title('Distribution of Year')
plt.xlabel('Founded')
plt.ylabel('Frequency')
plt.show()

# %%
plt.boxplot(ind_2020['Founded'].dropna())
plt.title('Distribution of Year')
plt.xlabel('Founded')
plt.show()

# %%
ind_2020['Founded'].replace(0, np.nan, inplace=True)

# %%
ind_2020['Founded'].fillna(ind_2020['Founded'].median(), inplace=True)

ind_2020['Founded'] = ind_2020['Founded'].astype(int)

# %%
ind_2020.head()
# Out:
#                Company/Brand  Founded HeadQuarter       Sector  \
# Date
# 2020-01-01             Keito     2016        Pune           AI
# 2020-01-01         FabHotels     2015    Gurugram  Hospitality
# 2020-01-01            Rupeek     2015   Bangalore      FinTech
# 2020-01-02           Univ.ai     2019   Bangalore       EdTech
# 2020-01-02  FPL Technologies     2016        Pune      Fintech
#
#                                                  What it does  \
# Date
# 2020-01-01                    Enterprise productivity startup
# 2020-01-01  Fabhotels is the online aggregator for hotel r...
# 2020-01-01  Rupeek is an online lending platform that spec...
# 2020-01-02  A distributed, global educational powerhouse t...
# 2020-01-02  OneScore app is built by FPL - Free credit sco...
#
#                                                      Founders  \
# Date
# 2020-01-01                                            Amal PS
# 2020-01-01                  Adarsh Manpuria, Vaibhav Aggarwal
# 2020-01-01            Amar Prabhu, Ashwin Soni, Sumit Maniyar
# 2020-01-02  Siddharth Das, Dr Rahul Dave, Dr Pavlos Protop...
# 2020-01-02                                       Anurag Sinha
#
#                                                      Investor    Amount($)  \
# Date
# 2020-01-01                                  Suma Soft Pvt Ltd     $160,000
# 2020-01-01             RB Investments Pte. Ltd, Goldman Sachs   $1,000,000
# 2020-01-01       KB Investment, Bertelsmann India Investments  $45,000,000
# 2020-01-02                               Kiran Mazumdar Shaw.  Undisclosed
# 2020-01-02  Matrix Partners India, Sequoia Capital India, ...  $10,000,000
#
#                  Stage Unnamed: 9  Year
# Date
# 2020-01-01  Seed Round        NaN  2020
# 2020-01-01    Series A        NaN  2020
# 2020-01-01    Series C        NaN  2020
# 2020-01-02    Series A        NaN  2020
# 2020-01-02    Series A        NaN  2020

# %%
ind_2020.drop('What it does',axis=1,inplace=True)

# %%
ind_2020.drop('Unnamed: 9',axis=1,inplace=True)

# %%
ind_2020.isna().sum()
# Out:
# Company/Brand    0
# Founded          0
# HeadQuarter      0
# Sector           0
# Founders         0
# Investor         0
# Amount($)        3
# Stage            0
# Year             0
# dtype: int64

# %%
ind_2020.head()
# Out:
#                Company/Brand  Founded HeadQuarter       Sector  \
# Date
# 2020-01-01             Keito     2016        Pune           AI
# 2020-01-01         FabHotels     2015    Gurugram  Hospitality
# 2020-01-01            Rupeek     2015   Bangalore      FinTech
# 2020-01-02           Univ.ai     2019   Bangalore       EdTech
# 2020-01-02  FPL Technologies     2016        Pune      Fintech
#
#                                                      Founders  \
# Date
# 2020-01-01                                            Amal PS
# 2020-01-01                  Adarsh Manpuria, Vaibhav Aggarwal
# 2020-01-01            Amar Prabhu, Ashwin Soni, Sumit Maniyar
# 2020-01-02  Siddharth Das, Dr Rahul Dave, Dr Pavlos Protop...
# 2020-01-02                                       Anurag Sinha
#
#                                                      Investor    Amount($)  \
# Date
# 2020-01-01                                  Suma Soft Pvt Ltd     $160,000
# 2020-01-01             RB Investments Pte. Ltd, Goldman Sachs   $1,000,000
# 2020-01-01       KB Investment, Bertelsmann India Investments  $45,000,000
# 2020-01-02                               Kiran Mazumdar Shaw.  Undisclosed
# 2020-01-02  Matrix Partners India, Sequoia Capital India, ...  $10,000,000
#
#                  Stage  Year
# Date
# 2020-01-01  Seed Round  2020
# 2020-01-01    Series A  2020
# 2020-01-01    Series C  2020
# 2020-01-02    Series A  2020
# 2020-01-02    Series A  2020

# %% [markdown]
# ## Converting the structure of the amt col,filling missing val with stats data,creating a substring to structure the sector column

# %%
ind_2020['Amount($)'].replace('', pd.np.nan, inplace=True)
ind_2020['Amount($)'] = ind_2020['Amount($)'].replace('undisclosed', np.nan)
# Out:
# C:\Users\GILBERT\AppData\Local\Temp\ipykernel_13168\4231441892.py:1: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead.
#   ind_2020['Amount($)'].replace('', pd.np.nan, inplace=True)

# %%
# if it is not already a string, convert it to string
if ind_2020['Amount($)'].dtype != 'object':
    ind_2020['Amount($)'] = ind_2020['Amount($)'].astype(str)

# # remove non-numeric characters from the 'Amount' column
ind_2020['Amount($)'] = ind_2020['Amount($)'].str.replace('[^\d\.]', '')

ind_2020['Amount($)'] = pd.to_numeric(ind_2020['Amount($)'])
# Out:
# C:\Users\GILBERT\AppData\Local\Temp\ipykernel_13168\2403162787.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   ind_2020['Amount($)'] = ind_2020['Amount($)'].str.replace('[^\d\.]', '')

# %%
ind_2020.head()
# Out:
#                Company/Brand  Founded HeadQuarter       Sector  \
# Date
# 2020-01-01             Keito     2016        Pune           AI
# 2020-01-01         FabHotels     2015    Gurugram  Hospitality
# 2020-01-01            Rupeek     2015   Bangalore      FinTech
# 2020-01-02           Univ.ai     2019   Bangalore       EdTech
# 2020-01-02  FPL Technologies     2016        Pune      Fintech
#
#                                                      Founders  \
# Date
# 2020-01-01                                            Amal PS
# 2020-01-01                  Adarsh Manpuria, Vaibhav Aggarwal
# 2020-01-01            Amar Prabhu, Ashwin Soni, Sumit Maniyar
# 2020-01-02  Siddharth Das, Dr Rahul Dave, Dr Pavlos Protop...
# 2020-01-02                                       Anurag Sinha
#
#                                                      Investor   Amount($)  \
# Date
# 2020-01-01                                  Suma Soft Pvt Ltd    160000.0
# 2020-01-01             RB Investments Pte. Ltd, Goldman Sachs   1000000.0
# 2020-01-01       KB Investment, Bertelsmann India Investments  45000000.0
# 2020-01-02                               Kiran Mazumdar Shaw.         NaN
# 2020-01-02  Matrix Partners India, Sequoia Capital India, ...  10000000.0
#
#                  Stage  Year
# Date
# 2020-01-01  Seed Round  2020
# 2020-01-01    Series A  2020
# 2020-01-01    Series C  2020
# 2020-01-02    Series A  2020
# 2020-01-02    Series A  2020

# %%
ind_2020['Amount($)'] = ind_2020['Amount($)'].fillna(0)

# %%
ind_2020.isna().sum()
# Out:
# Company/Brand    0
# Founded          0
# HeadQuarter      0
# Sector           0
# Founders         0
# Investor         0
# Amount($)        0
# Stage            0
# Year             0
# dtype: int64

# %%
plt.hist(ind_2020['Amount($)'], bins=20)
plt.title('Distribution of Amount')
plt.xlabel('Amount($)')
plt.ylabel('Frequency')
plt.show()

# %%
plt.boxplot(ind_2020['Amount($)'])
plt.title('Distribution of Amount')
plt.xlabel('Amount($)')
plt.show()

# %%
ind_2020['Amount($)'].replace(0, np.nan, inplace=True)

# %%
ind_2020.isna().sum()
# Out:
# Company/Brand      0
# Founded            0
# HeadQuarter        0
# Sector             0
# Founders           0
# Investor           0
# Amount($)        247
# Stage              0
# Year               0
# dtype: int64

# %%
ind_2020['Amount($)'].fillna(ind_2020['Amount($)'].median(), inplace=True)

ind_2020['Amount($)'] = ind_2020['Amount($)'].astype(int)

# %%
ind_2020.head()
# Out:
#                Company/Brand  Founded HeadQuarter       Sector  \
# Date
# 2020-01-01             Keito     2016        Pune           AI
# 2020-01-01         FabHotels     2015    Gurugram  Hospitality
# 2020-01-01            Rupeek     2015   Bangalore      FinTech
# 2020-01-02           Univ.ai     2019   Bangalore       EdTech
# 2020-01-02  FPL Technologies     2016        Pune      Fintech
#
#                                                      Founders  \
# Date
# 2020-01-01                                            Amal PS
# 2020-01-01                  Adarsh Manpuria, Vaibhav Aggarwal
# 2020-01-01            Amar Prabhu, Ashwin Soni, Sumit Maniyar
# 2020-01-02  Siddharth Das, Dr Rahul Dave, Dr Pavlos Protop...
# 2020-01-02                                       Anurag Sinha
#
#                                                      Investor  Amount($)  \
# Date
# 2020-01-01                                  Suma Soft Pvt Ltd     160000
# 2020-01-01             RB Investments Pte. Ltd, Goldman Sachs    1000000
# 2020-01-01       KB Investment, Bertelsmann India Investments   45000000
# 2020-01-02                               Kiran Mazumdar Shaw.    3000000
# 2020-01-02  Matrix Partners India, Sequoia Capital India, ...   10000000
#
#                  Stage  Year
# Date
# 2020-01-01  Seed Round  2020
# 2020-01-01    Series A  2020
# 2020-01-01    Series C  2020
# 2020-01-02    Series A  2020
# 2020-01-02    Series A  2020

# %%
# # Create a list of substrings to search for in the Sector column
tech = ['Mobile','Technology', 'Internet', 'Software', 'Hardware','SaaS','Blockchain','Apps','Information Services','SEM',
        'Artificial Intelligence','CleanTech','Aerospace','Robotics','Ai','PaaS','Medtech','Agritech','HR tech',
       'Tech','FoodTech','Safety tech','IoT','Legal tech','Infratech','Netwokring platform','Telecommunication','Cloud','Aero',
       'Virtual','Content','Photonics','app','Proptech','Deeptech','AR','VR','Agri tech','-Tech','AgriTech','IT','Network',
        'Data','HrTech','Foodtech','Spacetech','E-mobility','Automation','Logitech','HRTech','Drone','MLOps','Innovation',
       'BioTechnology','TaaS','network','equipment','SpaceTech','CRM','MarTech','Nanotechnology','Femtech','startup','AI']
fin = ['Lending','Finance','Insurance', 'Payments','Financial Services','Credit','Credit Cards','Mutual Funds',
       'Banking','Escrow','Venture','financial','Taxation','Capital','firm','Equity']
fint = ['NFT','Virtual Banking','FinTech','Fintech','Cryptocurrency','Crypto','Insurtech','InsurTech']
health = ['Health', 'Medical','Pharmaceutical','Health Diagnotics','Health Care','Hospital','Biotechnology','Biopharma',
         'Hygiene management','HealthTech','Healthcare','HealthCare','laboratory','Biotech','Healthtech','HeathTech',
         'Helathcare','Veterinary']
mkt = ['Brand Marketing','Marketing','Event Promotion','Market']
agric = ['Farming','Agriculture','Nutrition','Hauz Khas','Fishery']
con = ['Food','Food and Beverages','Dairy','Beverages','Beer','FMCG','Beverage']
econ = ['B2B','Shopping','E-Commerce','Trading Platform','E-commerce','E-marketplace','marketplace','e-commerce','Ecommerce',
        'E-market','Commerce','Trading platform']
cons = ['Wholesale','Consumer','Shoes','Packaging','Retail','Consulting','Food Delivery']
edu = ['E-Learning','EdTech','Education','Communities','Edtech','Preschool','School']
welln = ['Lifestyle','Beauty','Wellness','Cosmetics','Yoga','Skincare','D2C','Fitness','Lifestyle','Training']
real_est=['Real Estate','Home Decor','Accomodation','Interior design','Home Design','Home interior','Co-living',
          'Construction']
log = ['Logistics','Rental','Tourism','Travel','TravelTech','Transport','Transportation','Aviation','Mobility']

auto = ['Automotive','Electric vehicle','Industrial Automation','Vehicles','Automotive tech','Automobile','Tyre','car','Car',
       'Vehicle','Mechanical']
manu = ['Manufacturing']
ener = ['Renewable Energy','Solar','Energy','Energy Storage','Battery','Oil and Gas','Renewable','EV','Electricity',
       'purification','Renewables']
medi = ['Entertainment','Media','News','Video','Digital Media','FM','Publication','OTT','Social Network','Music',
        'Digital platform','Podcast','publishing','Blogging']
game = ['Gaming','Games','Sports']

style = ['Fashion','Jewelry','Eyeglasses','Eye Wear','Apparel','Dating','Celebrity','Eyewear','D2C Fashion','Matrimony',
         'Textiles','D2C jewellery','Foootwear','Arts']
hos =['Hospitality','Hotel','Leisure']


ind_2020['Sector_clean'] = 'Other'
ind_2020.loc[ind_2020['Sector'].str.contains('|'.join(tech)), 'Sector_clean'] = 'Technology'
ind_2020.loc[ind_2020['Sector'].str.contains('|'.join(fin)), 'Sector_clean'] = 'Finance'
ind_2020.loc[ind_2020['Sector'].str.contains('|'.join(health)), 'Sector_clean'] = 'Healthcare'
ind_2020.loc[ind_2020['Sector'].str.contains('|'.join(mkt)), 'Sector_clean'] = 'Marketing'
ind_2020.loc[ind_2020['Sector'].str.contains('|'.join(agric)), 'Sector_clean'] = 'Agriculture'
ind_2020.loc[ind_2020['Sector'].str.contains('|'.join(econ)), 'Sector_clean'] = 'E-Commerce'
ind_2020.loc[ind_2020['Sector'].str.contains('|'.join(edu)), 'Sector_clean'] = 'Education'
ind_2020.loc[ind_2020['Sector'].str.contains('|'.join(welln)), 'Sector_clean'] = 'Wellness/Beauty'
ind_2020.loc[ind_2020['Sector'].str.contains('|'.join(real_est)), 'Sector_clean'] = 'Real Estate'
ind_2020.loc[ind_2020['Sector'].str.contains('|'.join(log)), 'Sector_clean'] = 'Logistics'

ind_2020.loc[ind_2020['Sector'].str.contains('|'.join(auto)), 'Sector_clean'] = 'Automotive'
ind_2020.loc[ind_2020['Sector'].str.contains('|'.join(manu)), 'Sector_clean'] = 'Manufacture'
ind_2020.loc[ind_2020['Sector'].str.contains('|'.join(ener)), 'Sector_clean'] = 'Energy'
ind_2020.loc[ind_2020['Sector'].str.contains('|'.join(medi)), 'Sector_clean'] = 'Media/Entertainment'
ind_2020.loc[ind_2020['Sector'].str.contains('|'.join(hos)), 'Sector_clean'] = 'Hospitality'
ind_2020.loc[ind_2020['Sector'].str.contains('|'.join(style)), 'Sector_clean'] = 'Lifestyle'
ind_2020.loc[ind_2020['Sector'].str.contains('|'.join(cons)), 'Sector_clean'] = 'Consumer Services'
ind_2020.loc[ind_2020['Sector'].str.contains('|'.join(game)), 'Sector_clean'] = 'Gaming'
ind_2020.loc[ind_2020['Sector'].str.contains('|'.join(fint)), 'Sector_clean'] = 'FinTech'
ind_2020.loc[ind_2020['Sector'].str.contains('|'.join(con)), 'Sector_clean'] = 'Consumables'

# %%
ind_2020.head()
# Out:
#                Company/Brand  Founded HeadQuarter       Sector  \
# Date
# 2020-01-01             Keito     2016        Pune           AI
# 2020-01-01         FabHotels     2015    Gurugram  Hospitality
# 2020-01-01            Rupeek     2015   Bangalore      FinTech
# 2020-01-02           Univ.ai     2019   Bangalore       EdTech
# 2020-01-02  FPL Technologies     2016        Pune      Fintech
#
#                                                      Founders  \
# Date
# 2020-01-01                                            Amal PS
# 2020-01-01                  Adarsh Manpuria, Vaibhav Aggarwal
# 2020-01-01            Amar Prabhu, Ashwin Soni, Sumit Maniyar
# 2020-01-02  Siddharth Das, Dr Rahul Dave, Dr Pavlos Protop...
# 2020-01-02                                       Anurag Sinha
#
#                                                      Investor  Amount($)  \
# Date
# 2020-01-01                                  Suma Soft Pvt Ltd     160000
# 2020-01-01             RB Investments Pte. Ltd, Goldman Sachs    1000000
# 2020-01-01       KB Investment, Bertelsmann India Investments   45000000
# 2020-01-02                               Kiran Mazumdar Shaw.    3000000
# 2020-01-02  Matrix Partners India, Sequoia Capital India, ...   10000000
#
#                  Stage  Year Sector_clean
# Date
# 2020-01-01  Seed Round  2020   Technology
# 2020-01-01    Series A  2020  Hospitality
# 2020-01-01    Series C  2020      FinTech
# 2020-01-02    Series A  2020    Education
# 2020-01-02    Series A  2020      FinTech

# %%
ind_2020.drop('Sector',axis=1,inplace=True)

# %%
ind_2020= ind_2020.rename(columns={'Sector_clean': 'Sector'})

# %%
ind_2020.isna().sum()
# Out:
# Company/Brand    0
# Founded          0
# HeadQuarter      0
# Founders         0
# Investor         0
# Amount($)        0
# Stage            0
# Year             0
# Sector           0
# dtype: int64

# %%
ind_2020.head()
# Out:
#                Company/Brand  Founded HeadQuarter  \
# Date
# 2020-01-01             Keito     2016        Pune
# 2020-01-01         FabHotels     2015    Gurugram
# 2020-01-01            Rupeek     2015   Bangalore
# 2020-01-02           Univ.ai     2019   Bangalore
# 2020-01-02  FPL Technologies     2016        Pune
#
#                                                      Founders  \
# Date
# 2020-01-01                                            Amal PS
# 2020-01-01                  Adarsh Manpuria, Vaibhav Aggarwal
# 2020-01-01            Amar Prabhu, Ashwin Soni, Sumit Maniyar
# 2020-01-02  Siddharth Das, Dr Rahul Dave, Dr Pavlos Protop...
# 2020-01-02                                       Anurag Sinha
#
#                                                      Investor  Amount($)  \
# Date
# 2020-01-01                                  Suma Soft Pvt Ltd     160000
# 2020-01-01             RB Investments Pte. Ltd, Goldman Sachs    1000000
# 2020-01-01       KB Investment, Bertelsmann India Investments   45000000
# 2020-01-02                               Kiran Mazumdar Shaw.    3000000
# 2020-01-02  Matrix Partners India, Sequoia Capital India, ...   10000000
#
#                  Stage  Year       Sector
# Date
# 2020-01-01  Seed Round  2020   Technology
# 2020-01-01    Series A  2020  Hospitality
# 2020-01-01    Series C  2020      FinTech
# 2020-01-02    Series A  2020    Education
# 2020-01-02    Series A  2020      FinTech

# %%
if ind_2020.empty:
    print("No data found for the year 2018")
else:
    # Calculate the total funding by sector
    total_funding_by_sector = ind_2018.groupby('Sector')['Amount($)'].sum().reset_index()

    top_10_sectors = total_funding_by_sector.sort_values(by='Amount($)', ascending=False).head(10)

    ax = sns.barplot(data=top_10_sectors, x='Sector', y='Amount($)')
    ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
    plt.show()

# %% [markdown]
# ## checking the data shape / filling missing values/ creating a date series

# %%
ind_2021.head()
# Out:
#     Company/Brand  Founded HeadQuarter          Sector  \
# 0  Unbox Robotics   2019.0   Bangalore      AI startup
# 1          upGrad   2015.0      Mumbai          EdTech
# 2     Lead School   2012.0      Mumbai          EdTech
# 3         Bizongo   2015.0      Mumbai  B2B E-commerce
# 4        FypMoney   2021.0    Gurugram         FinTech
#
#                                         What it does  \
# 0  Unbox Robotics builds on-demand AI-driven ware...
# 1     UpGrad is an online higher education platform.
# 2  LEAD School offers technology based school tra...
# 3  Bizongo is a business-to-business online marke...
# 4  FypMoney is Digital NEO Bank for Teenagers, em...
#
#                                             Founders  \
# 0                        Pramod Ghadge, Shahid Memon
# 1  Mayank Kumar, Phalgun Kompalli, Ravijot Chugh,...
# 2                         Smita Deorah, Sumeet Mehta
# 3            Aniket Deb, Ankit Tomar, Sachin Agrawal
# 4                                      Kapil Banwari
#
#                                         Investor     Amount($)         Stage
# 0                    BEENEXT, Entrepreneur First    $1,200,000  Pre-series A
# 1       Unilazer Ventures, IIFL Asset Management  $120,000,000           NaN
# 2               GSV Ventures, Westbridge Capital   $30,000,000      Series D
# 3                         CDC Group, IDG Capital   $51,000,000      Series C
# 4  Liberatha Kallat, Mukesh Yadav, Dinesh Nagpal    $2,000,000          Seed

# %%
ind_2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1209 entries, 0 to 1208
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company/Brand  1209 non-null   object
#  1   Founded        1208 non-null   float64
#  2   HeadQuarter    1208 non-null   object
#  3   Sector         1209 non-null   object
#  4   What it does   1209 non-null   object
#  5   Founders       1205 non-null   object
#  6   Investor       1147 non-null   object
#  7   Amount($)      1206 non-null   object
#  8   Stage          781 non-null    object
# dtypes: float64(1), object(8)
# memory usage: 85.1+ KB

# %%
ind_2021.describe()
# Out:
#            Founded
# count  1208.000000
# mean   2016.655629
# std       4.517364
# min    1963.000000
# 25%    2015.000000
# 50%    2018.000000
# 75%    2020.000000
# max    2021.000000

# %%
ind_2021.isna().sum()
# Out:
# Company/Brand      0
# Founded            1
# HeadQuarter        1
# Sector             0
# What it does       0
# Founders           4
# Investor          62
# Amount($)          3
# Stage            428
# dtype: int64

# %%
# replace empty values with NaN
ind_2021['Sector'].replace('—', pd.np.nan, inplace=True)

ind_2021['Year']=2021
# Out:
# C:\Users\GILBERT\AppData\Local\Temp\ipykernel_13168\2320037695.py:2: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead.
#   ind_2021['Sector'].replace('—', pd.np.nan, inplace=True)

# %%
ind_2021.isna().sum()
# Out:
# Company/Brand      0
# Founded            1
# HeadQuarter        1
# Sector             0
# What it does       0
# Founders           4
# Investor          62
# Amount($)          3
# Stage            428
# Year               0
# dtype: int64

# %%
# create a DatetimeIndex with dates for the entire year
date_range = pd.date_range(start='2021-01-01', end='2021-12-31', freq='D')

# create a new column 'Date' with random dates within the year 2018
ind_2021['Date'] = np.random.choice(date_range, size=len(ind_2021))

ind_2021 = ind_2021.sort_values('Date')

ind_2021['Date'] = pd.to_datetime(ind_2021['Date'], format='%Y-%m-%d')

# %%
ind_2021.set_index('Date',inplace=True)

# %%
ind_2021['HeadQuarter'].ffill(inplace=True)

ind_2021['Stage'] = ind_2021['Stage'].fillna(ind_2021['Stage'].mode()[0])

# %%
mode_value = ind_2021['Investor'].mode()[0]
print(mode_value)
# Out:
# Inflection Point Ventures

# %%
ind_2021['Investor'] = ind_2021['Investor'].fillna(ind_2021['Investor'].mode()[0])

# %%
mode_value = ind_2021['Founders'].mode()[0]
print(mode_value)
# Out:
# Ashneer Grover, Shashvat Nakrani

# %%
ind_2021['Founders'] = ind_2021['Founders'].fillna(ind_2021['Founders'].mode()[0])

# %%
ind_2021.drop('What it does', axis=1,inplace=True)

# %% [markdown]
# ## Replacing the missing values in the founded column by using Statiscal means

# %%
plt.hist(ind_2021['Founded'], bins=20)
plt.title('Distribution of Year')
plt.xlabel('Founded')
plt.ylabel('Frequency')
plt.show()

# %%
ind_2021['Founded'] = pd.to_numeric(ind_2021['Founded'], errors='coerce')

# %%
ind_2021['Founded'] = ind_2021['Founded'].fillna(ind_2021['Founded'].median())

# %%
ind_2021.head(50)
# Out:
#                  Company/Brand  Founded      HeadQuarter  \
# Date
# 2021-01-01           Imagimake   2011.0           Mumbai
# 2021-01-01              Ruptok   2020.0        New Delhi
# 2021-01-01          BharatAgri   2017.0        Bangalore
# 2021-01-02         Yu Foodlabs   2020.0         Gurugram
# 2021-01-02             Cashify   2009.0         Gurugram
# 2021-01-02              Khabri   2017.0         Gurugram
# 2021-01-02           CometChat   2009.0           Mumbai
# 2021-01-02            Thingsup   2020.0             Pune
# 2021-01-03           kWh Bikes   2020.0        Bangalore
# 2021-01-03              Convin   2019.0        Bangalore
# 2021-01-03              Upgame   2017.0         Gurugram
# 2021-01-03      Artium Academy   2021.0           Mumbai
# 2021-01-03               Udaan   2016.0        Bangalore
# 2021-01-03     The Gourmet Jar   2012.0            Noida
# 2021-01-03           Nap Chief   2019.0           Mumbai
# 2021-01-04         PlanetSpark   2017.0         Gurugram
# 2021-01-04                Skit   2016.0        Bangalore
# 2021-01-04  Bella Vita Organic   2018.0         Gurugram
# 2021-01-05               BeatO   2015.0        New Delhi
# 2021-01-05           BlueLearn   2020.0              Goa
# 2021-01-05             Paytail   2020.0        New Delhi
# 2021-01-06          Xpresslane   2019.0        Bangalore
# 2021-01-06  Breathe Well-being   2015.0        New Delhi
# 2021-01-06                Hesa   2020.0        Hyderabad
# 2021-01-07             Toch.ai   2016.0           Mumbai
# 2021-01-07         Rage Coffee   2018.0        New Delhi
# 2021-01-07           FloCareer   2018.0        Bangalore
# 2021-01-07            ImaginXP   2013.0             Pune
# 2021-01-08             NeoDocs   2020.0           Mumbai
# 2021-01-08          HexaHealth   2019.0           Mumbai
# 2021-01-08             MoEVing   2021.0  Gurugram\t#REF!
# 2021-01-08              Bolkar   2018.0        Bangalore
# 2021-01-08             goSTOPS   2014.0        New Delhi
# 2021-01-08         Greenjoules   2018.0             Pune
# 2021-01-08       Ultraviolette   2021.0        Bangalore
# 2021-01-09           Rentomojo   2014.0        Bangalore
# 2021-01-10             Bizongo   2015.0           Mumbai
# 2021-01-10        Kenko Health   2019.0           Mumbai
# 2021-01-10          SK Finance   1994.0           Jaipur
# 2021-01-10              Bikayi   2019.0        Hyderabad
# 2021-01-10             Eduvanz   2016.0           Mumbai
# 2021-01-10           Homeville   2017.0           Mumbai
# 2021-01-10             Chqbook   2017.0         Gurugram
# 2021-01-11         MyMobiForce   2018.0            Noida
# 2021-01-11           Khatabook   2018.0        Bangalore
# 2021-01-12  SATYA MicroCapital   2017.0        New Delhi
# 2021-01-12             Neokred   2019.0        Bangalore
# 2021-01-12      ABL Workspaces   2017.0        New Delhi
# 2021-01-12             Wakefit   2014.0        Bangalore
# 2021-01-12                Miko   2015.0           Mumbai
#
#                                                        Sector  \
# Date
# 2021-01-01                              Innovation management
# 2021-01-01                                            FinTech
# 2021-01-01                                           AgriTech
# 2021-01-02                                   Food & Beverages
# 2021-01-02                                         E-commerce
# 2021-01-02                                              Media
# 2021-01-02                                  Computer Software
# 2021-01-02                                       IoT platform
# 2021-01-03                                         Automotive
# 2021-01-03                                       SaaS startup
# 2021-01-03                                             sports
# 2021-01-03                                              Music
# 2021-01-03                                         E-commerce
# 2021-01-03                                   Food & Beverages
# 2021-01-03                                  Apparel & Fashion
# 2021-01-04                               Education Management
# 2021-01-04                                         AI startup
# 2021-01-04                                         Healthcare
# 2021-01-05                                         Healthcare
# 2021-01-05                                             EdTech
# 2021-01-05                                 Financial Services
# 2021-01-06                                       Tech startup
# 2021-01-06                                         HealthCare
# 2021-01-06                                         IT startup
# 2021-01-07                                               SaaS
# 2021-01-07                                   Food & Beverages
# 2021-01-07                               Information Services
# 2021-01-07                                             EdTech
# 2021-01-08                                         Healthtech
# 2021-01-08                                         Healthtech
# 2021-01-08  MoEVing is India's only Electric Mobility focu...
# 2021-01-08                                     Social network
# 2021-01-08                                        Hospitality
# 2021-01-08                                   Renewable Energy
# 2021-01-08                                         Automotive
# 2021-01-09                                   Furniture Rental
# 2021-01-10                                     B2B E-commerce
# 2021-01-10                                         Insuretech
# 2021-01-10                                 Financial Services
# 2021-01-10                                         E-commerce
# 2021-01-10                                            FinTech
# 2021-01-10                  Information Technology & Services
# 2021-01-10                                            FinTech
# 2021-01-11                                           Internet
# 2021-01-11                                 Financial Services
# 2021-01-12                                            Banking
# 2021-01-12                                            FinTech
# 2021-01-12                                        Hospitality
# 2021-01-12                                          Furniture
# 2021-01-12                                           Robotics
#
#                                                      Founders  \
# Date
# 2021-01-01                        Disha Katharani, Ravi Kumar
# 2021-01-01                                        Ankur Gupta
# 2021-01-01                        Sai Gole, Siddharth Dialani
# 2021-01-02                         Bharat Bhalla, Varun Kapur
# 2021-01-02           Amit Sethi, Mandeep Manocha, Nakul Kumar
# 2021-01-02           Pulkit Sharma, Aankit Roy, Sandeep Singh
# 2021-01-02                                   Anuj, Anant Garg
# 2021-01-02                  Akshay Ghadage, Pranav Naiknavare
# 2021-01-03           Siddharth Janghu, Kartik Gupta, Anupriya
# 2021-01-03  Ashish Santhalia, Atul Shree, Bharat Patidar, ...
# 2021-01-03                                     Sameer Sawhney
# 2021-01-03                        Ashish Joshi, Nithya Sudhir
# 2021-01-03          Amod Malviya, Sujeet Kumar, Vaibhav Gupta
# 2021-01-03                                       Apeksha Jain
# 2021-01-03                                       Raghav Gupta
# 2021-01-04                       Maneesh Dhooper, Kunal Malik
# 2021-01-04                      Sourabh Gupta, Akshay Deshraj
# 2021-01-04                                       Aakash Anand
# 2021-01-05                                      Gautam Chopra
# 2021-01-05              Harish Uthayakumar, Shreyans Sancheti
# 2021-01-05                        AMIT CHATURVEDI, Vikas Garg
# 2021-01-06                                   Ashwin Koorakula
# 2021-01-06                        Aditya Kaicker, Rohan Verma
# 2021-01-06                    Vamsi Udayagiri, Hema Nandiraju
# 2021-01-07     Vinayak Shrivastav, Saket Dandotia, Alok Patil
# 2021-01-07                                       Bharat Sethi
# 2021-01-07                           Mohit Jain,  Mehul Bhatt
# 2021-01-07                                    Vidhika Rohatgi
# 2021-01-08         Nikunj Malpani, Anurag Meena, Pratik Lodha
# 2021-01-08  Vikas Chauhan, Ankur Gigras, Dr Aman Priya Khanna
# 2021-01-08     Anshuman Maheshwary, Dr Srihari Raju Kalidindi
# 2021-01-08  Abhishek Tripathi, Dhruv Kaushal, Prince Tripa...
# 2021-01-08                   Pallavi Agarwal, Pankaj Parwanda
# 2021-01-08  R. Sethunath, V S Shridhar, V. Radhika, Virara...
# 2021-01-08                Subramaniam Narayan, Niraj Rajmohan
# 2021-01-09                                   Geetansh Bamania
# 2021-01-10            Aniket Deb, Ankit Tomar, Sachin Agrawal
# 2021-01-10                         Aniruddha Sen, Dhiraj Goel
# 2021-01-10                                     Rajendra Setia
# 2021-01-10                  Sonakshi Nathani, Ashutosh Singla
# 2021-01-10          Atul Sashittal, Raheel Shah, Varun Chopra
# 2021-01-10                                  Madhusudan Sharma
# 2021-01-10            Vipul Sharma, Rajat Kumar, Sachin Arora
# 2021-01-11     Dheeraj Khatter, Himanshu Kumar, Kshitiz Saini
# 2021-01-11                       Ravish Naresh, Ashish Sonone
# 2021-01-12                                       Vivek Tiwari
# 2021-01-12                          Tarun Nazare, Rohith Reji
# 2021-01-12                         Ankur Gupta, Akshita Gupta
# 2021-01-12               Ankit Garg, Chaitanya Ramalingegowda
# 2021-01-12     Chintan Raikar, Prashant Iyengar, Sneh Vaswani
#
#                                                      Investor     Amount($)  \
# Date
# 2021-01-01  Roha Investment Managers, angel investor Saumi...       $500000
# 2021-01-01                                     Eclear Leasing      $1000000
# 2021-01-01                           Omnivore, India Quotient      $6500000
# 2021-01-02                         Manish Choksi, Varun Vakil      $1000000
# 2021-01-02         Bessemer Venture Partners, CDH Investments   $15,000,000
# 2021-01-02                          Inflection Point Ventures      $2000000
# 2021-01-02                               Signal Peak Ventures     $10000000
# 2021-01-02                                    GSF Accelerator    $1,000,000
# 2021-01-03                      Let’s Venture, Better Capital      $2000000
# 2021-01-03         9Unicorns Accelerator Fund, Sunder Nookala      $300,000
# 2021-01-03                         James Milner, Adam Lallana  $Undisclosed
# 2021-01-03                     Sonu Nigam, Whiteboard Capital       $750000
# 2021-01-03              Octahedron Capital, Moonstone Capital  $280,000,000
# 2021-01-03                                  DevX Venture Fund       $150000
# 2021-01-03                                      Titan Capital       $200000
# 2021-01-04  Binny Bansal, Deep Kalra, Dr Ashish Gupta, Gok...     $13000000
# 2021-01-04                                 Westbridge Capital     $23000000
# 2021-01-04                                     Ananta Capital     $10000000
# 2021-01-05                                  W Health Ventures      $5000000
# 2021-01-05  100X.VC﻿,﻿ Titan Capital, Rahul Mathur, Gaurav...       $400000
# 2021-01-05                                      Cholamandalam      $1500000
# 2021-01-06  Point One Capital, Yatra Angel Network (YAN), ...       $400000
# 2021-01-06  Stanford Angels and Entrepreneurs India, Anjal...      $1000000
# 2021-01-06                       Venture Catalysts, 9unicorns      $2000000
# 2021-01-07                          Inflection Point Ventures     $11000000
# 2021-01-07                               Sixth Sense Ventures      $5000000
# 2021-01-07                                 Data Point Capital      $5700000
# 2021-01-07                                  Venture Catalysts    $1,500,000
# 2021-01-08             Y Combinator, 9Unicorns, Titan Capital  $Undisclosed
# 2021-01-08           Omidyar Network India, Chiratae Ventures      $4500000
# 2021-01-08                                           $5000000          Seed
# 2021-01-08                                   GSF, Pras Hanuma   Undisclosed
# 2021-01-08                                  IAN, Yuj Ventures      $1000000
# 2021-01-08                                 Blue Ashva Capital      $4500000
# 2021-01-08                                    TVS Motor, Zoho    $150000000
# 2021-01-09                                Accel, Bain Capital     $10000000
# 2021-01-10                             CDC Group, IDG Capital   $51,000,000
# 2021-01-10                                     BEENEXT, Orios      $1700000
# 2021-01-10  IIFL Wealth, TPG Growth, Norwest Venture Partners     $53000000
# 2021-01-10                              Sequoia Capital India     $10000000
# 2021-01-10  InCred Financial Services, Vivriti Capital, No...   $10,000,000
# 2021-01-10                    9Unicorns, Varanium NexGen Fund      $7000000
# 2021-01-10            Aavishkaar Capital, Rajiv Dadlani Group      $5000000
# 2021-01-11                                   Bharat Inclusion      $1400000
# 2021-01-11      Tribe Capital, Moore Strategic Ventures (MSV)    $100000000
# 2021-01-12           responsAbility Investments, Blue Orchard     $10000000
# 2021-01-12         Virenxia Group, Rajesh Jain, Nitin Agarwal       $500000
# 2021-01-12                                               Wurk      $600,000
# 2021-01-12                                                SIG     $20000000
# 2021-01-12        Chiratae Ventures, YourNest Venture Capital    $6,000,000
#
#                    Stage  Year
# Date
# 2021-01-01  Pre-series A  2021
# 2021-01-01          Seed  2021
# 2021-01-01      Series A  2021
# 2021-01-02  Pre-series A  2021
# 2021-01-02          Seed  2021
# 2021-01-02  Pre-series A  2021
# 2021-01-02      Series A  2021
# 2021-01-02          Seed  2021
# 2021-01-03          Seed  2021
# 2021-01-03      Pre-seed  2021
# 2021-01-03          Seed  2021
# 2021-01-03          Seed  2021
# 2021-01-03          Seed  2021
# 2021-01-03          Seed  2021
# 2021-01-03          Seed  2021
# 2021-01-04      Series B  2021
# 2021-01-04      Series B  2021
# 2021-01-04          Seed  2021
# 2021-01-05  Pre-series B  2021
# 2021-01-05      Pre-seed  2021
# 2021-01-05          Seed  2021
# 2021-01-06      Pre-seed  2021
# 2021-01-06  Pre-series A  2021
# 2021-01-06          Seed  2021
# 2021-01-07      Series A  2021
# 2021-01-07          Seed  2021
# 2021-01-07      Series A  2021
# 2021-01-07          Seed  2021
# 2021-01-08      Pre-seed  2021
# 2021-01-08          Seed  2021
# 2021-01-08          Seed  2021
# 2021-01-08          Seed  2021
# 2021-01-08  Pre-series A  2021
# 2021-01-08      Series A  2021
# 2021-01-08      Series C  2021
# 2021-01-09          Seed  2021
# 2021-01-10      Series C  2021
# 2021-01-10  Pre-series A  2021
# 2021-01-10      Series F  2021
# 2021-01-10      Series A  2021
# 2021-01-10          Debt  2021
# 2021-01-10          Seed  2021
# 2021-01-10  Pre-series B  2021
# 2021-01-11  Pre-series A  2021
# 2021-01-11      Series C  2021
# 2021-01-12          Seed  2021
# 2021-01-12          Seed  2021
# 2021-01-12  Pre-series A  2021
# 2021-01-12      Series C  2021
# 2021-01-12          Seed  2021

# %% [markdown]
# ## Filtering & replacing missing values in the the amount col, containing the sector col into categories by putting them in substrings

# %%
# replace empty values with NaN
ind_2021['Amount($)'].replace('', pd.np.nan, inplace=True)
# Out:
# C:\Users\GILBERT\AppData\Local\Temp\ipykernel_13168\3156858020.py:2: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead.
#   ind_2021['Amount($)'].replace('', pd.np.nan, inplace=True)

# %%
ind_2021['Amount($)'] = ind_2021['Amount($)'].replace('undisclosed', np.nan)

# %%
# if it is not already a string, convert it to string
if ind_2021['Amount($)'].dtype != 'object':
    ind_2021['Amount($)'] = ind_2021['Amount($)'].astype(str)

# # remove non-numeric characters from the 'Amount' column
ind_2021['Amount($)'] = ind_2021['Amount($)'].str.replace('[^\d\.]', '')

ind_2021['Amount($)'] = pd.to_numeric(ind_2021['Amount($)'])
# Out:
# C:\Users\GILBERT\AppData\Local\Temp\ipykernel_13168\803264993.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   ind_2021['Amount($)'] = ind_2021['Amount($)'].str.replace('[^\d\.]', '')

# %%
# Replace NaN values with 0
ind_2021['Amount($)'] = ind_2021['Amount($)'].fillna(0)

# %%
ind_2021.isna().sum()
# Out:
# Company/Brand    0
# Founded          0
# HeadQuarter      0
# Sector           0
# Founders         0
# Investor         0
# Amount($)        0
# Stage            0
# Year             0
# dtype: int64

# %%
plt.hist(ind_2021['Amount($)'], bins=20)
plt.title('Distribution of Amount')
plt.xlabel('Amount($)')
plt.ylabel('Frequency')
plt.show()

# %%
plt.boxplot(ind_2021['Amount($)'])
plt.title('Distribution of Amount')
plt.xlabel('Amount($)')
plt.show()

# %%
ind_2021['Amount($)'].replace(0, np.nan, inplace=True)

# %%
# Fill missing values with median value
ind_2021['Amount($)'].fillna(ind_2021['Amount($)'].mean(), inplace=True)

ind_2021['Amount($)'] = ind_2021['Amount($)'].astype(int)

# %%
ind_2021.isna().sum()
# Out:
# Company/Brand    0
# Founded          0
# HeadQuarter      0
# Sector           0
# Founders         0
# Investor         0
# Amount($)        0
# Stage            0
# Year             0
# dtype: int64

# %%
ind_2021.head()
# Out:
#            Company/Brand  Founded HeadQuarter                 Sector  \
# Date
# 2021-01-01     Imagimake   2011.0      Mumbai  Innovation management
# 2021-01-01        Ruptok   2020.0   New Delhi                FinTech
# 2021-01-01    BharatAgri   2017.0   Bangalore               AgriTech
# 2021-01-02   Yu Foodlabs   2020.0    Gurugram       Food & Beverages
# 2021-01-02       Cashify   2009.0    Gurugram             E-commerce
#
#                                             Founders  \
# Date
# 2021-01-01               Disha Katharani, Ravi Kumar
# 2021-01-01                               Ankur Gupta
# 2021-01-01               Sai Gole, Siddharth Dialani
# 2021-01-02                Bharat Bhalla, Varun Kapur
# 2021-01-02  Amit Sethi, Mandeep Manocha, Nakul Kumar
#
#                                                      Investor  Amount($)  \
# Date
# 2021-01-01  Roha Investment Managers, angel investor Saumi...     500000
# 2021-01-01                                     Eclear Leasing    1000000
# 2021-01-01                           Omnivore, India Quotient    6500000
# 2021-01-02                         Manish Choksi, Varun Vakil    1000000
# 2021-01-02         Bessemer Venture Partners, CDH Investments   15000000
#
#                    Stage  Year
# Date
# 2021-01-01  Pre-series A  2021
# 2021-01-01          Seed  2021
# 2021-01-01      Series A  2021
# 2021-01-02  Pre-series A  2021
# 2021-01-02          Seed  2021

# %%
# # Create a list of substrings to search for in the Sector column
tech = ['Mobile','Technology', 'Internet', 'Software', 'Hardware','SaaS','Blockchain','Apps','Information Services','SEM',
        'Artificial Intelligence','CleanTech','Aerospace','Robotics','Ai','PaaS','Medtech','Agritech','HR tech',
       'Tech','FoodTech','Safety tech','IoT','Legal tech','Infratech','Netwokring platform','Telecommunication','Cloud','Aero',
       'Virtual','Content','Photonics','app','Proptech','Deeptech','AR','VR','Agri tech','-Tech','AgriTech','IT','Network',
        'Data','HrTech','Foodtech','Spacetech','E-mobility','Automation','Logitech','HRTech','Drone','MLOps','Innovation',
       'BioTechnology','TaaS','network','equipment','SpaceTech','CRM','MarTech','Nanotechnology','Femtech','startup','AI']
fin = ['Lending','Finance','Insurance', 'Payments','Financial Services','Credit','Credit Cards','Mutual Funds',
       'Banking','Escrow','Venture','financial','Taxation','Capital','firm','Equity']
fint = ['NFT','Virtual Banking','FinTech','Fintech','Cryptocurrency','Crypto','Insurtech','InsurTech']
health = ['Health', 'Medical','Pharmaceutical','Health Diagnotics','Health Care','Hospital','Biotechnology','Biopharma',
         'Hygiene management','HealthTech','Healthcare','HealthCare','laboratory','Biotech','Healthtech','HeathTech',
         'Helathcare','Veterinary']
mkt = ['Brand Marketing','Marketing','Event Promotion','Market']
agric = ['Farming','Agriculture','Nutrition','Hauz Khas','Fishery']
con = ['Food','Food and Beverages','Dairy','Beverages','Beer','FMCG']
econ = ['B2B','Shopping','E-Commerce','Trading Platform','E-commerce','E-marketplace','marketplace','e-commerce','Ecommerce',
        'E-market','Commerce','Trading platform']
cons = ['Wholesale','Consumer','Shoes','Packaging','Retail','Consulting','Food Delivery']
edu = ['E-Learning','EdTech','Education','Communities','Edtech','Preschool','School']
welln = ['Lifestyle','Beauty','Wellness','Cosmetics','Yoga','Skincare','D2C','Fitness','Lifestyle','Training']
real_est=['Real Estate','Home Decor','Accomodation','Interior design','Home Design','Home interior','Co-living',
          'Construction']
log = ['Logistics','Rental','Tourism','Travel','TravelTech','Transport','Transportation','Aviation','Mobility']

auto = ['Automotive','Electric vehicle','Industrial Automation','Vehicles','Automotive tech','Automobile','Tyre','car','Car',
       'Vehicle','Mechanical']
manu = ['Manufacturing']
ener = ['Renewable Energy','Solar','Energy','Energy Storage','Battery','Oil and Gas','Renewable','EV','Electricity',
       'purification','Renewables']
medi = ['Entertainment','Media','News','Video','Digital Media','FM','Publication','OTT','Social Network','Music',
        'Digital platform','Podcast','publishing','Blogging']
Game = ['Gaming','Games','Sports']

style = ['Fashion','Jewelry','Eyeglasses','Eye Wear','Apparel','Dating','Celebrity','Eyewear','D2C Fashion','Matrimony',
         'Textiles','D2C jewellery','Foootwear','Arts']
hos =['Hospitality','Hotel','Leisure']


ind_2021['Sector_clean'] = 'Other'
ind_2021.loc[ind_2021['Sector'].str.contains('|'.join(tech)), 'Sector_clean'] = 'Technology'
ind_2021.loc[ind_2021['Sector'].str.contains('|'.join(fin)), 'Sector_clean'] = 'Finance'
ind_2021.loc[ind_2021['Sector'].str.contains('|'.join(health)), 'Sector_clean'] = 'Healthcare'
ind_2021.loc[ind_2021['Sector'].str.contains('|'.join(mkt)), 'Sector_clean'] = 'Marketing'
ind_2021.loc[ind_2021['Sector'].str.contains('|'.join(agric)), 'Sector_clean'] = 'Agriculture'
ind_2021.loc[ind_2021['Sector'].str.contains('|'.join(econ)), 'Sector_clean'] = 'E-Commerce'
ind_2021.loc[ind_2021['Sector'].str.contains('|'.join(edu)), 'Sector_clean'] = 'Education'
ind_2021.loc[ind_2021['Sector'].str.contains('|'.join(welln)), 'Sector_clean'] = 'Wellness/Beauty'
ind_2021.loc[ind_2021['Sector'].str.contains('|'.join(real_est)), 'Sector_clean'] = 'Real Estate'
ind_2021.loc[ind_2021['Sector'].str.contains('|'.join(log)), 'Sector_clean'] = 'Logistics'

ind_2021.loc[ind_2021['Sector'].str.contains('|'.join(auto)), 'Sector_clean'] = 'Automotive'
ind_2021.loc[ind_2021['Sector'].str.contains('|'.join(manu)), 'Sector_clean'] = 'Manufacture'
ind_2021.loc[ind_2021['Sector'].str.contains('|'.join(ener)), 'Sector_clean'] = 'Energy'
ind_2021.loc[ind_2021['Sector'].str.contains('|'.join(medi)), 'Sector_clean'] = 'Media/Entertainment'
ind_2021.loc[ind_2021['Sector'].str.contains('|'.join(hos)), 'Sector_clean'] = 'Hospitality'
ind_2021.loc[ind_2021['Sector'].str.contains('|'.join(style)), 'Sector_clean'] = 'Lifestyle'
ind_2021.loc[ind_2021['Sector'].str.contains('|'.join(cons)), 'Sector_clean'] = 'Consumer Services'
ind_2021.loc[ind_2021['Sector'].str.contains('|'.join(game)), 'Sector_clean'] = 'Gaming'
ind_2021.loc[ind_2021['Sector'].str.contains('|'.join(fint)), 'Sector_clean'] = 'FinTech'
ind_2021.loc[ind_2021['Sector'].str.contains('|'.join(con)), 'Sector_clean'] = 'Consumables'

# %%
# replace the value in row  of Column1 with NaN & fill/replace with mode

ind_2021['HeadQuarter'] = ind_2021['HeadQuarter'].replace('Food & Beverages', np.nan)
ind_2021['HeadQuarter'] = ind_2021['HeadQuarter'].replace('Pharmaceuticals\t#REF!', np.nan)
ind_2021['HeadQuarter'] = ind_2021['HeadQuarter'].replace('Online Media#REF!', np.nan)

ind_2021['HeadQuarter'] = ind_2021['HeadQuarter'].replace('Gurugram\t#REF!', 'Gurugram')
# df_2021.loc[1054, 'Sector'] = 'Technology'


ind_2021['HeadQuarter'] = ind_2021['HeadQuarter'].fillna(ind_2021['HeadQuarter'].mode()[0])

# %%
# filling the gaps with appropriate naming convention

ind_2021['Sector'] = ind_2021['Sector'].replace('Primary Business is Development and Manufacturing of Novel Healthcare Products in Effervescent forms using imported propriety ingredients.', 'Healthcare')
ind_2021['Sector'] = ind_2021['Sector'].replace('Primary Business is Development and Manufacturing of Novel Healthcare Products in Effervescent forms using imported propriety ingredients.', 'Healthcare')   
ind_2021['Sector'] = ind_2021['Sector'].replace('MoEVing is Indias only Electric Mobility focused Technology Platform with a vision to accelerate EV adoption in India.', 'Energy')
ind_2021['Sector'] = ind_2021['Sector'].replace('Sochcast is an Audio experiences company that give the listener and creators an Immersive Audio experience.', 'Media/Entertainment')

# %%
ind_2021.head()
# Out:
#            Company/Brand  Founded HeadQuarter                 Sector  \
# Date
# 2021-01-01     Imagimake   2011.0      Mumbai  Innovation management
# 2021-01-01        Ruptok   2020.0   New Delhi                FinTech
# 2021-01-01    BharatAgri   2017.0   Bangalore               AgriTech
# 2021-01-02   Yu Foodlabs   2020.0    Gurugram       Food & Beverages
# 2021-01-02       Cashify   2009.0    Gurugram             E-commerce
#
#                                             Founders  \
# Date
# 2021-01-01               Disha Katharani, Ravi Kumar
# 2021-01-01                               Ankur Gupta
# 2021-01-01               Sai Gole, Siddharth Dialani
# 2021-01-02                Bharat Bhalla, Varun Kapur
# 2021-01-02  Amit Sethi, Mandeep Manocha, Nakul Kumar
#
#                                                      Investor  Amount($)  \
# Date
# 2021-01-01  Roha Investment Managers, angel investor Saumi...     500000
# 2021-01-01                                     Eclear Leasing    1000000
# 2021-01-01                           Omnivore, India Quotient    6500000
# 2021-01-02                         Manish Choksi, Varun Vakil    1000000
# 2021-01-02         Bessemer Venture Partners, CDH Investments   15000000
#
#                    Stage  Year Sector_clean
# Date
# 2021-01-01  Pre-series A  2021   Technology
# 2021-01-01          Seed  2021      FinTech
# 2021-01-01      Series A  2021   Technology
# 2021-01-02  Pre-series A  2021  Consumables
# 2021-01-02          Seed  2021   E-Commerce

# %%
ind_2021.isna().sum()
# Out:
# Company/Brand    0
# Founded          0
# HeadQuarter      0
# Sector           0
# Founders         0
# Investor         0
# Amount($)        0
# Stage            0
# Year             0
# Sector_clean     0
# dtype: int64

# %%
ind_2021.drop(ind_2021.columns[-7], axis=1,inplace=True)

# %%
ind_2021= ind_2021.rename(columns={'Sector_clean': 'Sector'})

# %%
ind_2021['Founded'] = ind_2021['Founded'].astype(int)

# %%
ind_2021.head()
# Out:
#            Company/Brand  Founded HeadQuarter  \
# Date
# 2021-01-01     Imagimake     2011      Mumbai
# 2021-01-01        Ruptok     2020   New Delhi
# 2021-01-01    BharatAgri     2017   Bangalore
# 2021-01-02   Yu Foodlabs     2020    Gurugram
# 2021-01-02       Cashify     2009    Gurugram
#
#                                             Founders  \
# Date
# 2021-01-01               Disha Katharani, Ravi Kumar
# 2021-01-01                               Ankur Gupta
# 2021-01-01               Sai Gole, Siddharth Dialani
# 2021-01-02                Bharat Bhalla, Varun Kapur
# 2021-01-02  Amit Sethi, Mandeep Manocha, Nakul Kumar
#
#                                                      Investor  Amount($)  \
# Date
# 2021-01-01  Roha Investment Managers, angel investor Saumi...     500000
# 2021-01-01                                     Eclear Leasing    1000000
# 2021-01-01                           Omnivore, India Quotient    6500000
# 2021-01-02                         Manish Choksi, Varun Vakil    1000000
# 2021-01-02         Bessemer Venture Partners, CDH Investments   15000000
#
#                    Stage  Year       Sector
# Date
# 2021-01-01  Pre-series A  2021   Technology
# 2021-01-01          Seed  2021      FinTech
# 2021-01-01      Series A  2021   Technology
# 2021-01-02  Pre-series A  2021  Consumables
# 2021-01-02          Seed  2021   E-Commerce

# %%
if ind_2021.empty:
    print("No data found for the year 2018")
else:
    # Calculate the total funding by sector
    total_funding_by_sector = ind_2021.groupby('Sector')['Amount($)'].sum().reset_index()

    top_10_sectors = total_funding_by_sector.sort_values(by='Amount($)', ascending=False).head(10)

    ax = sns.barplot(data=top_10_sectors, x='Sector', y='Amount($)')
    ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
    plt.show()

# %% [markdown]
# ## filling missing values in 2018 with merged data, checking the correlation,converting amount col to float

# %%
# Compute the correlation matrix
combined_ind = pd.concat([ind_2019, ind_2020, ind_2021], axis=0)

correlation_matrix = combined_ind.corr()

print(correlation_matrix)
# Out:
#             Founded  Amount($)      Year
# Founded    1.000000   0.040112  0.151314
# Amount($)  0.040112   1.000000  0.115326
# Year       0.151314   0.115326  1.000000

# %%
ind_2018.isna().sum()
# Out:
# Company/Brand      0
# Stage              0
# Amount($)          0
# Year               0
# Founded          526
# HeadQuarter        0
# Sector             0
# dtype: int64

# %%
plt.hist(combined_ind['Founded'], bins=50)
plt.title('Distribution of Year')
plt.xlabel('Founded')
plt.ylabel('Frequency')
plt.show()

# %%
# Calculate the median of the column
median_value = combined_ind['Founded'].median()

# %%
ind_2018['Founded'].fillna(median_value, inplace=True)

# %%
ind_2018.isna().sum()
# Out:
# Company/Brand    0
# Stage            0
# Amount($)        0
# Year             0
# Founded          0
# HeadQuarter      0
# Sector           0
# dtype: int64

# %%
ind_2018['Founded'] = ind_2018['Founded'].astype(int)

# %%
ind_2018.head()
# Out:
#                               Company/Brand     Stage  Amount($)  Year  \
# Date
# 2018-01-01  Hashtag Loyalty Private Limited      Seed    5800000  2018
# 2018-01-01                        Simulanis      Seed     500000  2018
# 2018-01-01     Wellthy Therapeutics Pvt Ltd      Seed  135000000  2018
# 2018-01-01                            mfine  Series A    4200000  2018
# 2018-01-02            Pandorum Technologies  Series A    3600000  2018
#
#             Founded HeadQuarter             Sector
# Date
# 2018-01-01     2016      Mumbai  Consumer Services
# 2018-01-01     2016   New Delhi    Wellness/Beauty
# 2018-01-01     2016      Mumbai         Automotive
# 2018-01-01     2016   Bengaluru         Automotive
# 2018-01-02     2016   Bengaluru         Healthcare

# %%
ind_2018["Amount($)"] = ind_2018["Amount($)"].astype(float)

ind_2019["Amount($)"] = ind_2019["Amount($)"].astype(float)

ind_2020["Amount($)"] = ind_2020["Amount($)"].astype(float)

ind_2021["Amount($)"] = ind_2021["Amount($)"].astype(float)

# %%
# save dataframe to a CSV file
ind_2018.to_csv('start-2018.csv',index_label='Date')
ind_2019.to_csv('start-2019.csv',index_label='Date')
ind_2020.to_csv('start-2020.csv',index_label='Date')
ind_2021.to_csv('start-2021.csv',index_label='Date')

# %%
ind_2018.head()
# Out:
#                               Company/Brand     Stage    Amount($)  Year  \
# Date
# 2018-01-01  Hashtag Loyalty Private Limited      Seed    5800000.0  2018
# 2018-01-01                        Simulanis      Seed     500000.0  2018
# 2018-01-01     Wellthy Therapeutics Pvt Ltd      Seed  135000000.0  2018
# 2018-01-01                            mfine  Series A    4200000.0  2018
# 2018-01-02            Pandorum Technologies  Series A    3600000.0  2018
#
#             Founded HeadQuarter             Sector
# Date
# 2018-01-01     2016      Mumbai  Consumer Services
# 2018-01-01     2016   New Delhi    Wellness/Beauty
# 2018-01-01     2016      Mumbai         Automotive
# 2018-01-01     2016   Bengaluru         Automotive
# 2018-01-02     2016   Bengaluru         Healthcare

# %%
# Check the unique values in the Stage column
print(df["Stage"].unique())

# Map the different variations of funding stages to standardized categories
stage_map = {
    "Seed Funding": "Seed",
    "Seed/ Angel Funding": "Seed",
    "Seed / Angel Funding": "Seed",
    "Seed/Angel Funding": "Seed",
    "Angel Funding": "Angel",
    "Pre-Series A": "Pre-Series A",
    "Pre Series A": "Pre-Series A",
    "Pre-Series A Funding": "Pre-Series A",
    "Pre Series A Funding": "Pre-Series A",
    "Series A": "Series A",
    "Series B": "Series B",
    "Series C": "Series C",
    "Series D": "Series D",
    "Series E": "Series E",
    "Series F": "Series F",
    "Series G": "Series G",
    "Series H": "Series H"
}

df["Stage"] = df["Stage"].map(stage_map)

# Check the unique values in the Stage column again
print(df["Stage"].unique())
